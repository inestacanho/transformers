# %% [markdown]
# <a href="https://colab.research.google.com/github/inestacanho/transformers/blob/main/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/history.zip -d //content/
# Out:
# Archive:  /content/history.zip
#   inflating: //content/history/Aalborg.txt
#   inflating: //content/history/Aarhus.txt
#   inflating: //content/history/Aasiaat.txt
#   inflating: //content/history/Abadan.txt
#   inflating: //content/history/Abakan.txt
#   inflating: //content/history/Aberdeen.txt
#   inflating: //content/history/Abha.txt
#   inflating: //content/history/Abidjan.txt
#   inflating: //content/history/Abu Dhabi.txt
#   inflating: //content/history/Abu Simbel.txt
#   inflating: //content/history/Abuja.txt
#   inflating: //content/history/Acapulco.txt
#   inflating: //content/history/Accra.txt
#   inflating: //content/history/Adak Island.txt
#   inflating: //content/history/Adana.txt
#   inflating: //content/history/Addis Ababa.txt
#   inflating: //content/history/Adelaide.txt
#   inflating: //content/history/Aden.txt
#   inflating: //content/history/Adiyaman.txt
#   inflating: //content/history/Agadir.txt
#   inflating: //content/history/Agana.txt
#   inflating: //content/history/Agartala.txt
#   inflating: //content/history/Agra.txt
#   inflating: //content/history/Aguadilla.txt
#   inflating: //content/history/Aguascalientes.txt
#   inflating: //content/history/Ahe.txt
#   inflating: //content/history/Ahmedabad.txt
#   inflating: //content/history/Ahwaz.txt
#   inflating: //content/history/Aitutaki.txt
#   inflating: //content/history/Aizwal.txt
#   inflating: //content/history/Ajaccio.txt
#   inflating: //content/history/Akron.txt
#   inflating: //content/history/Aktau.txt
#   inflating: //content/history/Aktyubinsk.txt
#   inflating: //content/history/Akulivik.txt
#   inflating: //content/history/Akureyri.txt
#   inflating: //content/history/Al-Ula.txt
#   inflating: //content/history/Alamosa.txt
#   inflating: //content/history/Alanya.txt
#   inflating: //content/history/Albuquerque.txt
#   inflating: //content/history/Albury.txt
#   inflating: //content/history/Alderney.txt
#   inflating: //content/history/Alesund.txt
#   inflating: //content/history/Alexandria.txt
#   inflating: //content/history/Alexandroupolis.txt
#   inflating: //content/history/Alghero.txt
#   inflating: //content/history/Alicante.txt
#   inflating: //content/history/Alice Springs.txt
#   inflating: //content/history/Allahabad.txt
#   inflating: //content/history/Alluitsup Paa.txt
#   inflating: //content/history/Alma-ata.txt
#   inflating: //content/history/Almeirim.txt
#   inflating: //content/history/Almeria.txt
#   inflating: //content/history/Alofi.txt
#   inflating: //content/history/Alor Setar.txt
#   inflating: //content/history/Altenrhein.txt
#   inflating: //content/history/Amami.txt
#   inflating: //content/history/Amman.txt
#   inflating: //content/history/Amritsar.txt
#   inflating: //content/history/Amsterdam.txt
#   inflating: //content/history/Anapa.txt
#   inflating: //content/history/Anchorage.txt
#   inflating: //content/history/Ancona.txt
#   inflating: //content/history/Andizhan.txt
#   inflating: //content/history/Angeles City.txt
#   inflating: //content/history/Angelsey.txt
#   inflating: //content/history/Angoon.txt
#   inflating: //content/history/Angouleme.txt
#   inflating: //content/history/Ankara.txt
#   inflating: //content/history/Annaba.txt
#   inflating: //content/history/Anqing.txt
#   inflating: //content/history/Anshan.txt
#   inflating: //content/history/Anshun.txt
#   inflating: //content/history/Antalya.txt
#   inflating: //content/history/Antananarivo.txt
#   inflating: //content/history/Antigua.txt
#   inflating: //content/history/Antofagasta.txt
#   inflating: //content/history/Antsiranana.txt
#   inflating: //content/history/Antwerp.txt
#   inflating: //content/history/Aomori.txt
#   inflating: //content/history/Apatity.txt
#   inflating: //content/history/Aqaba.txt
#   inflating: //content/history/Aracaju.txt
#   inflating: //content/history/Aracatuba.txt
#   inflating: //content/history/Arba Minch.txt
#   inflating: //content/history/Arctic Bay.txt
#   inflating: //content/history/Ardabil.txt
#   inflating: //content/history/Arequipa.txt
#   inflating: //content/history/Arica.txt
#   inflating: //content/history/Arkhangelsk.txt
#   inflating: //content/history/Armenia.txt
#   inflating: //content/history/Armidale.txt
#   inflating: //content/history/Arrecife.txt
#   inflating: //content/history/Arusha.txt
#   inflating: //content/history/Arutua.txt
#   inflating: //content/history/Arvidsjaur.txt
#   inflating: //content/history/Asaba.txt
#   inflating: //content/history/Asahikawa.txt
#   inflating: //content/history/Asheville.txt
#   inflating: //content/history/Ashkhabad.txt
#   inflating: //content/history/Asmara.txt
#   inflating: //content/history/Asosa.txt
#   inflating: //content/history/Astrakhan.txt
#   inflating: //content/history/Astypalaia.txt
#   inflating: //content/history/Asuncion.txt
#   inflating: //content/history/Aswan.txt
#   inflating: //content/history/Asyut.txt
#   inflating: //content/history/Athens.txt
#   inflating: //content/history/Atiu Island.txt
#   inflating: //content/history/Atlanta.txt
#   inflating: //content/history/Atlantic City.txt
#   inflating: //content/history/Atyrau.txt
#   inflating: //content/history/Auckland.txt
#   inflating: //content/history/Augsburg.txt
#   inflating: //content/history/Aurangabad.txt
#   inflating: //content/history/Aurillac.txt
#   inflating: //content/history/Aurukun.txt
#   inflating: //content/history/Avignon.txt
#   inflating: //content/history/Aviles.txt
#   inflating: //content/history/Axum.txt
#   inflating: //content/history/Ayacucho.txt
#   inflating: //content/history/Babelthuap.txt
#   inflating: //content/history/Bacolod.txt
#   inflating: //content/history/Badajoz.txt
#   inflating: //content/history/Bagan.txt
#   inflating: //content/history/Baghdad.txt
#   inflating: //content/history/Bahar Dar.txt
#   inflating: //content/history/Bahawalpur.txt
#   inflating: //content/history/Bahrain.txt
#   inflating: //content/history/Baia Mare.txt
#   inflating: //content/history/Baie Comeau.txt
#   inflating: //content/history/Baise.txt
#   inflating: //content/history/Baishan.txt
#   inflating: //content/history/Bakalalan.txt
#   inflating: //content/history/Bakersfield.txt
#   inflating: //content/history/Bakhtaran.txt
#   inflating: //content/history/Baku.txt
#   inflating: //content/history/Balikpapan.txt
#   inflating: //content/history/Baltimore.txt
#   inflating: //content/history/Bamako.txt
#   inflating: //content/history/Banda Aceh.txt
#   inflating: //content/history/Bandar Abbas.txt
#   inflating: //content/history/Bandar Lengeh.txt
#   inflating: //content/history/Bandar Mahshahr.txt
#   inflating: //content/history/Bandar Seri Begawan.txt
#   inflating: //content/history/Bandung.txt
#   inflating: //content/history/Bangalore.txt
#   inflating: //content/history/Bangkok.txt
#   inflating: //content/history/Bangui.txt
#   inflating: //content/history/Banja Luka.txt
#   inflating: //content/history/Banjarmasin.txt
#   inflating: //content/history/Banjul.txt
#   inflating: //content/history/Baotou.txt
#   inflating: //content/history/Bar Harbor.txt
#   inflating: //content/history/Barcelona.txt
#   inflating: //content/history/Bari.txt
#   inflating: //content/history/Bario.txt
#   inflating: //content/history/Barisal.txt
#   inflating: //content/history/Barnaul.txt
#   inflating: //content/history/Baroda.txt
#   inflating: //content/history/Barquisimeto.txt
#   inflating: //content/history/Barra.txt
#   inflating: //content/history/Barrancabermeja.txt
#   inflating: //content/history/Barranquilla.txt
#   inflating: //content/history/Barreiras.txt
#   inflating: //content/history/Basrah.txt
#   inflating: //content/history/Bastia.txt
#   inflating: //content/history/Batagay-Alyta.txt
#   inflating: //content/history/Batam.txt
#   inflating: //content/history/Baton Rouge.txt
#   inflating: //content/history/Batticaloa.txt
#   inflating: //content/history/Batumi.txt
#   inflating: //content/history/Bau-Bau.txt
#   inflating: //content/history/Bauru.txt
#   inflating: //content/history/Bayannur.txt
#   inflating: //content/history/Beauvais.txt
#   inflating: //content/history/Bedourie.txt
#   inflating: //content/history/Beihai.txt
#   inflating: //content/history/Beijing.txt
#   inflating: //content/history/Beirut.txt
#   inflating: //content/history/Belem.txt
#   inflating: //content/history/Belfast.txt
#   inflating: //content/history/Belgaum.txt
#   inflating: //content/history/Belgorod.txt
#   inflating: //content/history/Belgrade.txt
#   inflating: //content/history/Belize City.txt
#   inflating: //content/history/Belo Horizonte.txt
#   inflating: //content/history/Bemidji.txt
#   inflating: //content/history/Benbecula.txt
#   inflating: //content/history/Benghazi.txt
#   inflating: //content/history/Bengkulu.txt
#   inflating: //content/history/Benin.txt
#   inflating: //content/history/Berbera.txt
#   inflating: //content/history/Bergamo.txt
#   inflating: //content/history/Bergen.txt
#   inflating: //content/history/Berlin.txt
#   inflating: //content/history/Bermuda.txt
#   inflating: //content/history/Bern.txt
#   inflating: //content/history/Beslan.txt
#   inflating: //content/history/Beziers.txt
#   inflating: //content/history/Bhaunagar.txt
#   inflating: //content/history/Bhopal.txt
#   inflating: //content/history/Bhubaneswar.txt
#   inflating: //content/history/Bhuj.txt
#   inflating: //content/history/Biak.txt
#   inflating: //content/history/Bilbao.txt
#   inflating: //content/history/Billings.txt
#   inflating: //content/history/Bima.txt
#   inflating: //content/history/Binghamton.txt
#   inflating: //content/history/Bingol.txt
#   inflating: //content/history/Bintulu.txt
#   inflating: //content/history/Biratnagar.txt
#   inflating: //content/history/Birdsville.txt
#   inflating: //content/history/Birjand.txt
#   inflating: //content/history/Birmingham.txt
#   inflating: //content/history/Bishkek.txt
#   inflating: //content/history/Biskra.txt
#   inflating: //content/history/Bissau.txt
#   inflating: //content/history/Blackall.txt
#   inflating: //content/history/Blackpool.txt
#   inflating: //content/history/Blagoveschensk.txt
#   inflating: //content/history/Blantyre.txt
#   inflating: //content/history/Bloemfontein.txt
#   inflating: //content/history/Bocas Del Toro.txt
#   inflating: //content/history/Bodaibo.txt
#   inflating: //content/history/Bodrum.txt
#   inflating: //content/history/Boende.txt
#   inflating: //content/history/Bogota.txt
#   inflating: //content/history/Boise.txt
#   inflating: //content/history/Bojnourd.txt
#   inflating: //content/history/Bologna.txt
#   inflating: //content/history/Bolzano.txt
#   inflating: //content/history/Bora Bora.txt
#   inflating: //content/history/Bordeaux.txt
#   inflating: //content/history/Bordj Badji Mokhtar.txt
#   inflating: //content/history/Borlange.txt
#   inflating: //content/history/Bosaso.txt
#   inflating: //content/history/Boston.txt
#   inflating: //content/history/Boulia.txt
#   inflating: //content/history/Bourgas.txt
#   inflating: //content/history/Bournemouth.txt
#   inflating: //content/history/Bozeman.txt
#   inflating: //content/history/Bradford.txt
#   inflating: //content/history/Brasilia.txt
#   inflating: //content/history/Bratislava.txt
#   inflating: //content/history/Bratsk.txt
#   inflating: //content/history/Brazzaville.txt
#   inflating: //content/history/Bremen.txt
#   inflating: //content/history/Bridgetown.txt
#   inflating: //content/history/Brindisi.txt
#   inflating: //content/history/Brisbane.txt
#   inflating: //content/history/Bristol.txt
#   inflating: //content/history/Brive.txt
#   inflating: //content/history/Brno.txt
#   inflating: //content/history/Broken Hill.txt
#   inflating: //content/history/Bronnoysund.txt
#   inflating: //content/history/Brussels.txt
#   inflating: //content/history/Bucaramanga.txt
#   inflating: //content/history/Bucharest.txt
#   inflating: //content/history/Budapest.txt
#   inflating: //content/history/Buenos Aires.txt
#   inflating: //content/history/Bujumbura.txt
#   inflating: //content/history/Buka Island.txt
#   inflating: //content/history/Bukhara.txt
#   inflating: //content/history/Bukoba.txt
#   inflating: //content/history/Bulawayo.txt
#   inflating: //content/history/Bulolo.txt
#   inflating: //content/history/Bundaberg.txt
#   inflating: //content/history/Burgos.txt
#   inflating: //content/history/Buri Ram.txt
#   inflating: //content/history/Burketown.txt
#   inflating: //content/history/Burnie.txt
#   inflating: //content/history/Busan.txt
#   inflating: //content/history/Bushehr.txt
#   inflating: //content/history/Busuanga.txt
#   inflating: //content/history/Butuan.txt
#   inflating: //content/history/Bydgoszcz.txt
#   inflating: //content/history/Ca Mau.txt
#   inflating: //content/history/Cacador.txt
#   inflating: //content/history/Cacoal.txt
#   inflating: //content/history/Caen.txt
#   inflating: //content/history/Cagayan de Oro City.txt
#   inflating: //content/history/Cagliari.txt
#   inflating: //content/history/Cairns.txt
#   inflating: //content/history/Cairo.txt
#   inflating: //content/history/Cajamarca.txt
#   inflating: //content/history/Calabar.txt
#   inflating: //content/history/Calbayog City.txt
#   inflating: //content/history/Caldas Novas.txt
#   inflating: //content/history/Calgary.txt
#   inflating: //content/history/Cali.txt
#   inflating: //content/history/Calicut.txt
#   inflating: //content/history/Camaguey.txt
#   inflating: //content/history/Cambridge Bay.txt
#   inflating: //content/history/Camiguin.txt
#   inflating: //content/history/Campbeltown.txt
#   inflating: //content/history/Campeche.txt
#   inflating: //content/history/Campina Grande.txt
#   inflating: //content/history/Campinas.txt
#   inflating: //content/history/Campo Grande.txt
#   inflating: //content/history/Can Tho.txt
#   inflating: //content/history/Canakkale.txt
#   inflating: //content/history/Canberra.txt
#   inflating: //content/history/Cancun.txt
#   inflating: //content/history/Cap Haitien.txt
#   inflating: //content/history/Cape Dorset.txt
#   inflating: //content/history/Cape Girardeau.txt
#   inflating: //content/history/Cape Town.txt
#   inflating: //content/history/Caracas.txt
#   inflating: //content/history/Carcassonne.txt
#   inflating: //content/history/Cardiff.txt
#   inflating: //content/history/Casablanca.txt
#   inflating: //content/history/Cascavel.txt
#   inflating: //content/history/Castres.txt
#   inflating: //content/history/Castries.txt
#   inflating: //content/history/Catania.txt
#   inflating: //content/history/Caticlan.txt
#   inflating: //content/history/Catumbela.txt
#   inflating: //content/history/Cayenne.txt
#   inflating: //content/history/Cayman Brac.txt
#   inflating: //content/history/Cayo Largo del Sur.txt
#   inflating: //content/history/Cebu.txt
#   inflating: //content/history/Cedar City.txt
#   inflating: //content/history/Cedar Rapids.txt
#   inflating: //content/history/Chah Bahar.txt
#   inflating: //content/history/Champaign.txt
#   inflating: //content/history/Chandigarh.txt
#   inflating: //content/history/Changchun.txt
#   inflating: //content/history/Changde.txt
#   inflating: //content/history/Changzhi.txt
#   inflating: //content/history/Changzhou.txt
#   inflating: //content/history/Chania.txt
#   inflating: //content/history/Chapeco.txt
#   inflating: //content/history/Charleroi.txt
#   inflating: //content/history/Charlottetown.txt
#   inflating: //content/history/Chattanooga.txt
#   inflating: //content/history/Cheboksary.txt
#   inflating: //content/history/Chelyabinsk.txt
#   inflating: //content/history/Chengdu.txt
#   inflating: //content/history/Cherepovets.txt
#   inflating: //content/history/Chetumal.txt
#   inflating: //content/history/Cheyenne.txt
#   inflating: //content/history/Chiang Mai.txt
#   inflating: //content/history/Chiang Rai.txt
#   inflating: //content/history/Chibougamau.txt
#   inflating: //content/history/Chicago.txt
#   inflating: //content/history/Chiclayo.txt
#   inflating: //content/history/Chifeng.txt
#   inflating: //content/history/Chimkent.txt
#   inflating: //content/history/Chios.txt
#   inflating: //content/history/Chipata.txt
#   inflating: //content/history/Chisasibi.txt
#   inflating: //content/history/Chisinau.txt
#   inflating: //content/history/Chitral.txt
#   inflating: //content/history/Chittagong.txt
#   inflating: //content/history/Chokurdah.txt
#   inflating: //content/history/Chongju.txt
#   inflating: //content/history/Chongqing.txt
#   inflating: //content/history/Christchurch.txt
#   inflating: //content/history/Christmas Island.txt
#   inflating: //content/history/Chuathbaluk.txt
#   inflating: //content/history/Chumphon.txt
#   inflating: //content/history/Churchill Falls.txt
#   inflating: //content/history/Cincinnati.txt
#   inflating: //content/history/Circle.txt
#   inflating: //content/history/Ciudad Del Carmen.txt
#   inflating: //content/history/Ciudad del Este.txt
#   inflating: //content/history/Ciudad Juarez.txt
#   inflating: //content/history/Ciudad Obregon.txt
#   inflating: //content/history/Ciudad Victoria.txt
#   inflating: //content/history/Clermont-Ferrand.txt
#   inflating: //content/history/Cleveland.txt
#   inflating: //content/history/Cloncurry.txt
#   inflating: //content/history/Cluj-napoca.txt
#   inflating: //content/history/Cobija.txt
#   inflating: //content/history/Coca.txt
#   inflating: //content/history/Cochabamba.txt
#   inflating: //content/history/Cockburn Town.txt
#   inflating: //content/history/Coff's Harbour.txt
#   inflating: //content/history/Coimbatore.txt
#   inflating: //content/history/Cold Bay.txt
#   inflating: //content/history/Colima.txt
#   inflating: //content/history/Cologne.txt
#   inflating: //content/history/Colombo.txt
#   inflating: //content/history/Colorado Springs.txt
#   inflating: //content/history/Comiso.txt
#   inflating: //content/history/Comodoro Rivadavia.txt
#   inflating: //content/history/Conakry.txt
#   inflating: //content/history/Connaught.txt
#   inflating: //content/history/Constanta.txt
#   inflating: //content/history/Coober Pedy.txt
#   inflating: //content/history/Coolangatta.txt
#   inflating: //content/history/Copenhagen.txt
#   inflating: //content/history/Copiapo.txt
#   inflating: //content/history/Coral Harbour.txt
#   inflating: //content/history/Corumba.txt
#   inflating: //content/history/Cotabato.txt
#   inflating: //content/history/Cotonou.txt
#   inflating: //content/history/Cox's Bazar.txt
#   inflating: //content/history/Cozumel.txt
#   inflating: //content/history/Craiova.txt
#   inflating: //content/history/Cucuta.txt
#   inflating: //content/history/Cuiaba.txt
#   inflating: //content/history/Culebra Island.txt
#   inflating: //content/history/Culiacan.txt
#   inflating: //content/history/Cumana.txt
#   inflating: //content/history/Cuneo.txt
#   inflating: //content/history/Cunnamulla.txt
#   inflating: //content/history/Curitiba.txt
#   inflating: //content/history/Cuzco.txt
#   inflating: //content/history/Cyclades Islands.txt
#   inflating: //content/history/Dakar.txt
#   inflating: //content/history/Dalian.txt
#   inflating: //content/history/Dallas.txt
#   inflating: //content/history/Dammam.txt
#   inflating: //content/history/Danang.txt
#   inflating: //content/history/Dandong.txt
#   inflating: //content/history/Daocheng.txt
#   inflating: //content/history/Daqing.txt
#   inflating: //content/history/Dar Es Salaam.txt
#   inflating: //content/history/Datong.txt
#   inflating: //content/history/Dawei.txt
#   inflating: //content/history/Dawson Creek.txt
#   inflating: //content/history/Dayong.txt
#   inflating: //content/history/Dayton.txt
#   inflating: //content/history/Daytona Beach.txt
#   inflating: //content/history/Dazhou.txt
#   inflating: //content/history/Deadhorse.txt
#   inflating: //content/history/Deauville.txt
#   inflating: //content/history/Debrecen.txt
#   inflating: //content/history/Dehra Dun.txt
#   inflating: //content/history/Delhi.txt
#   inflating: //content/history/Deline.txt
#   inflating: //content/history/Denizli.txt
#   inflating: //content/history/Denpasar.txt
#   inflating: //content/history/Denver.txt
#   inflating: //content/history/Dera Ghazi Khan.txt
#   inflating: //content/history/Derby.txt
#   inflating: //content/history/Des Moines.txt
#   inflating: //content/history/Detroit.txt
#   inflating: //content/history/Dezful.txt
#   inflating: //content/history/Dhaka.txt
#   inflating: //content/history/Dienbienphu.txt
#   inflating: //content/history/Dijon.txt
#   inflating: //content/history/Dili.txt
#   inflating: //content/history/Dillingham.txt
#   inflating: //content/history/Dimapur.txt
#   inflating: //content/history/Dinard.txt
#   inflating: //content/history/Dipolog.txt
#   inflating: //content/history/Dire Dawa.txt
#   inflating: //content/history/Diyabakir.txt
#   inflating: //content/history/Djanet.txt
#   inflating: //content/history/Djerba.txt
#   inflating: //content/history/Djibouti.txt
#   inflating: //content/history/Dnepropetrovsk.txt
#   inflating: //content/history/Dodge City.txt
#   inflating: //content/history/Doha.txt
#   inflating: //content/history/Dominica.txt
#   inflating: //content/history/Donetsk.txt
#   inflating: //content/history/Dong Hoi.txt
#   inflating: //content/history/Dongsheng.txt
#   inflating: //content/history/Dongying.txt
#   inflating: //content/history/Doomadgee.txt
#   inflating: //content/history/Dortmund.txt
#   inflating: //content/history/Douala.txt
#   inflating: //content/history/Dresden.txt
#   inflating: //content/history/Dubai.txt
#   inflating: //content/history/Dubbo.txt
#   inflating: //content/history/Dublin.txt
#   inflating: //content/history/Dubrovnik.txt
#   inflating: //content/history/Duesseldorf.txt
#   inflating: //content/history/Duluth.txt
#   inflating: //content/history/Dumaguete.txt
#   inflating: //content/history/Dundee.txt
#   inflating: //content/history/Dunedin.txt
#   inflating: //content/history/Dunhuang.txt
#   inflating: //content/history/Durango.txt
#   inflating: //content/history/Durban.txt
#   inflating: //content/history/Dushanbe.txt
#   inflating: //content/history/Dzhambul.txt
#   inflating: //content/history/East London.txt
#   inflating: //content/history/East Midlands.txt
#   inflating: //content/history/Easter Island.txt
#   inflating: //content/history/Eastmain River.txt
#   inflating: //content/history/Eastsound.txt
#   inflating: //content/history/Eday.txt
#   inflating: //content/history/Edinburgh.txt
#   inflating: //content/history/Edmonton.txt
#   inflating: //content/history/Egilsstadir.txt
#   inflating: //content/history/Eindhoven.txt
#   inflating: //content/history/Eirunepe.txt
#   inflating: //content/history/El Aaiún.txt
#   inflating: //content/history/El Bayadh.txt
#   inflating: //content/history/El Calafate.txt
#   inflating: //content/history/El Fasher.txt
#   inflating: //content/history/El Paso.txt
#   inflating: //content/history/Elat.txt
#   inflating: //content/history/Elazig.txt
#   inflating: //content/history/Elcho Island.txt
#   inflating: //content/history/Eldoret.txt
#   inflating: //content/history/Elista.txt
#   inflating: //content/history/Enfidha.txt
#   inflating: //content/history/Entebbe.txt
#   inflating: //content/history/Enugu.txt
#   inflating: //content/history/Erbil.txt
#   inflating: //content/history/Erechim.txt
#   inflating: //content/history/Erfurt.txt
#   inflating: //content/history/Erie.txt
#   inflating: //content/history/Erzincan.txt
#   inflating: //content/history/Erzurum.txt
#   inflating: //content/history/Escanaba.txt
#   inflating: //content/history/Esfahan.txt
#   inflating: //content/history/Esquel.txt
#   inflating: //content/history/Evansville.txt
#   inflating: //content/history/Exeter.txt
#   inflating: //content/history/Fagernes.txt
#   inflating: //content/history/Fairbanks.txt
#   inflating: //content/history/Faisalabad.txt
#   inflating: //content/history/Fak Fak.txt
#   inflating: //content/history/Fakarava.txt
#   inflating: //content/history/False Pass.txt
#   inflating: //content/history/Fergana.txt
#   inflating: //content/history/Fes.txt
#   inflating: //content/history/Flin Flon.txt
#   inflating: //content/history/Flinders Island.txt
#   inflating: //content/history/Florence.txt
#   inflating: //content/history/Flores.txt
#   inflating: //content/history/Florianopolis.txt
#   inflating: //content/history/Fort Chipewyan.txt
#   inflating: //content/history/Fort Frances.txt
#   inflating: //content/history/Fort Good Hope.txt
#   inflating: //content/history/Fort Hope.txt
#   inflating: //content/history/Fort Lauderdale.txt
#   inflating: //content/history/Fort Mcmurray.txt
#   inflating: //content/history/Fort Myers.txt
#   inflating: //content/history/Fort Saint John.txt
#   inflating: //content/history/Fort Simpson.txt
#   inflating: //content/history/Fort Wayne.txt
#   inflating: //content/history/Fort Yukon.txt
#   inflating: //content/history/Fortaleza.txt
#   inflating: //content/history/Foshan.txt
#   inflating: //content/history/Foz Do Iguacu.txt
#   inflating: //content/history/Francistown.txt
#   inflating: //content/history/Frankfurt.txt
#   inflating: //content/history/Fredericton.txt
#   inflating: //content/history/Freetown.txt
#   inflating: //content/history/Fresno.txt
#   inflating: //content/history/Friedrichshafen.txt
#   inflating: //content/history/Fuerteventura.txt
#   inflating: //content/history/Fujeirah.txt
#   inflating: //content/history/Fukuoka.txt
#   inflating: //content/history/Funafuti.txt
#   inflating: //content/history/Funchal.txt
#   inflating: //content/history/Fuyang.txt
#   inflating: //content/history/Fuzhou.txt
#   inflating: //content/history/Gaberone.txt
#   inflating: //content/history/Gabes.txt
#   inflating: //content/history/Gafsa.txt
#   inflating: //content/history/Galapagos.txt
#   inflating: //content/history/Galcaio.txt
#   inflating: //content/history/Gallivare.txt
#   inflating: //content/history/Gambell.txt
#   inflating: //content/history/Gamètì.txt
#   inflating: //content/history/Ganzhou.txt
#   inflating: //content/history/Garoua.txt
#   inflating: //content/history/Gaua Island.txt
#   inflating: //content/history/Gaziantep.txt
#   inflating: //content/history/Gdansk.txt
#   inflating: //content/history/Gelendzhik.txt
#   inflating: //content/history/Geneina.txt
#   inflating: //content/history/Geneva.txt
#   inflating: //content/history/Genoa.txt
#   inflating: //content/history/Geraldton.txt
#   inflating: //content/history/Ghadames.txt
#   inflating: //content/history/Ghardaia.txt
#   inflating: //content/history/Gibraltar.txt
#   inflating: //content/history/Gilgit.txt
#   inflating: //content/history/Gillette.txt
#   inflating: //content/history/Gjoa Haven.txt
#   inflating: //content/history/Glasgow.txt
#   inflating: //content/history/Glendive.txt
#   inflating: //content/history/Goa.txt
#   inflating: //content/history/Gode.txt
#   inflating: //content/history/Godthaab.txt
#   inflating: //content/history/Goiania.txt
#   inflating: //content/history/Golmud.txt
#   inflating: //content/history/Goma.txt
#   inflating: //content/history/Gondar.txt
#   inflating: //content/history/Gorakhpur.txt
#   inflating: //content/history/Gorgan.txt
#   inflating: //content/history/Gorno-Altaysk.txt
#   inflating: //content/history/Gorontalo.txt
#   inflating: //content/history/Gothenborg.txt
#   inflating: //content/history/Governador Valadares.txt
#   inflating: //content/history/Graciosa Island.txt
#   inflating: //content/history/Gran Canaria.txt
#   inflating: //content/history/Granada.txt
#   inflating: //content/history/Grand Canyon.txt
#   inflating: //content/history/Grand Forks.txt
#   inflating: //content/history/Grand Rapids.txt
#   inflating: //content/history/Grande Prairie.txt
#   inflating: //content/history/Graz.txt
#   inflating: //content/history/Great Exuma.txt
#   inflating: //content/history/Greensboro.txt
#   inflating: //content/history/Grise Fiord.txt
#   inflating: //content/history/Groningen.txt
#   inflating: //content/history/Groote Eylandt.txt
#   inflating: //content/history/Guadalajara.txt
#   inflating: //content/history/Guanaja.txt
#   inflating: //content/history/Guangyuan.txt
#   inflating: //content/history/Guangzhou.txt
#   inflating: //content/history/Guantanamo.txt
#   inflating: //content/history/Guarapuava.txt
#   inflating: //content/history/Guatemala City.txt
#   inflating: //content/history/Guayaquil.txt
#   inflating: //content/history/Guernsey.txt
#   inflating: //content/history/Guilin.txt
#   inflating: //content/history/Guiyang.txt
#   inflating: //content/history/Gurney.txt
#   inflating: //content/history/Guwahati.txt
#   inflating: //content/history/Gwadar.txt
#   inflating: //content/history/Gwalior.txt
#   inflating: //content/history/Gyumri.txt
#   inflating: //content/history/Haa Dhaalu Atoll.txt
#   inflating: //content/history/Hachijojima.txt
#   inflating: //content/history/Hagerstown.txt
#   inflating: //content/history/Haifa.txt
#   inflating: //content/history/Haikou.txt
#   inflating: //content/history/Hailar.txt
#   inflating: //content/history/Haiphong.txt
#   inflating: //content/history/Hakodate.txt
#   inflating: //content/history/Hall Beach.txt
#   inflating: //content/history/Halmstad.txt
#   inflating: //content/history/Hamadan.txt
#   inflating: //content/history/Hamburg.txt
#   inflating: //content/history/Hami.txt
#   inflating: //content/history/Hammerfest.txt
#   inflating: //content/history/Hanamaki.txt
#   inflating: //content/history/Handan.txt
#   inflating: //content/history/Hangzhou.txt
#   inflating: //content/history/Hannover.txt
#   inflating: //content/history/Hanoi.txt
#   inflating: //content/history/Hao Island.txt
#   inflating: //content/history/Harare.txt
#   inflating: //content/history/Harbin.txt
#   inflating: //content/history/Hargeisa.txt
#   inflating: //content/history/Harrisburg.txt
#   inflating: //content/history/Hassi Messaoud.txt
#   inflating: //content/history/Hat Yai.txt
#   inflating: //content/history/Hatay.txt
#   inflating: //content/history/Haugesund.txt
#   inflating: //content/history/Havana.txt
#   inflating: //content/history/Havre-Saint-Pierre.txt
#   inflating: //content/history/Hawarden.txt
#   inflating: //content/history/Hefei.txt
#   inflating: //content/history/Heihe.txt
#   inflating: //content/history/Helsinki.txt
#   inflating: //content/history/Hemavan.txt
#   inflating: //content/history/Heraklion.txt
#   inflating: //content/history/Herat.txt
#   inflating: //content/history/Hermosillo.txt
#   inflating: //content/history/Hervey Bay.txt
#   inflating: //content/history/Hibbing.txt
#   inflating: //content/history/Hierro.txt
#   inflating: //content/history/High Level.txt
#   inflating: //content/history/Hilo.txt
#   inflating: //content/history/Hilton Head Island.txt
#   inflating: //content/history/Hiroshima.txt
#   inflating: //content/history/Ho Chi Minh City.txt
#   inflating: //content/history/Hobart.txt
#   inflating: //content/history/Hodeidah.txt
#   inflating: //content/history/Hoedspruit.txt
#   inflating: //content/history/Hohhot.txt
#   inflating: //content/history/Hokitika.txt
#   inflating: //content/history/Holguin.txt
#   inflating: //content/history/Holman Island.txt
#   inflating: //content/history/Hong Kong.txt
#   inflating: //content/history/Honiara.txt
#   inflating: //content/history/Honningsvag.txt
#   inflating: //content/history/Honolulu.txt
#   inflating: //content/history/Hoonah.txt
#   inflating: //content/history/Hotan.txt
#   inflating: //content/history/Houston.txt
#   inflating: //content/history/Huambo.txt
#   inflating: //content/history/Huangshan.txt
#   inflating: //content/history/Huatulco.txt
#   inflating: //content/history/Hubli.txt
#   inflating: //content/history/Huntsville.txt
#   inflating: //content/history/Hurghada.txt
#   inflating: //content/history/Huánuco.txt
#   inflating: //content/history/Hydaburg.txt
#   inflating: //content/history/Hyderabad.txt
#   inflating: //content/history/Hyeres.txt
#   inflating: //content/history/Iasi.txt
#   inflating: //content/history/Ibadan.txt
#   inflating: //content/history/Ibague.txt
#   inflating: //content/history/Ibiza.txt
#   inflating: //content/history/Idaho Falls.txt
#   inflating: //content/history/Igarka.txt
#   inflating: //content/history/Igdir.txt
#   inflating: //content/history/Igiugig.txt
#   inflating: //content/history/Igloolik.txt
#   inflating: //content/history/Ikaria.txt
#   inflating: //content/history/Iloilo.txt
#   inflating: //content/history/Ilorin.txt
#   inflating: //content/history/Ilulissat.txt
#   inflating: //content/history/Imphal.txt
#   inflating: //content/history/Indianapolis.txt
#   inflating: //content/history/Indore.txt
#   inflating: //content/history/Inhambane.txt
#   inflating: //content/history/Innsbruck.txt
#   inflating: //content/history/International Falls.txt
#   inflating: //content/history/Inukjuak.txt
#   inflating: //content/history/Inuvik.txt
#   inflating: //content/history/Invercargill.txt
#   inflating: //content/history/Inverness.txt
#   inflating: //content/history/Ioannina.txt
#   inflating: //content/history/Ipiales.txt
#   inflating: //content/history/Ipoh.txt
#   inflating: //content/history/Iqaluit.txt
#   inflating: //content/history/Iquique.txt
#   inflating: //content/history/Iquitos.txt
#   inflating: //content/history/Irkutsk.txt
#   inflating: //content/history/Isafjordur.txt
#   inflating: //content/history/Isiro.txt
#   inflating: //content/history/Islamabad.txt
#   inflating: //content/history/Islay.txt
#   inflating: //content/history/Isle Of Man.txt
#   inflating: //content/history/Isparta.txt
#   inflating: //content/history/Istanbul.txt
#   inflating: //content/history/Itaituba.txt
#   inflating: //content/history/Ittoqqortoormiit.txt
#   inflating: //content/history/Ivalo.txt
#   inflating: //content/history/Ivano-Frankivsk.txt
#   inflating: //content/history/Ivujivik.txt
#   inflating: //content/history/Iwakuni.txt
#   inflating: //content/history/Izhevsk.txt
#   inflating: //content/history/Izmir.txt
#   inflating: //content/history/Jabalpur.txt
#   inflating: //content/history/Jacksonville.txt
#   inflating: //content/history/Jaipur.txt
#   inflating: //content/history/Jakarta.txt
#   inflating: //content/history/Jalapa.txt
#   inflating: //content/history/Jambi.txt
#   inflating: //content/history/Jammu.txt
#   inflating: //content/history/Jamnagar.txt
#   inflating: //content/history/Janakpur.txt
#   inflating: //content/history/Jauja.txt
#   inflating: //content/history/Jayapura.txt
#   inflating: //content/history/Jeddah.txt
#   inflating: //content/history/Jerez.txt
#   inflating: //content/history/Jersey.txt
#   inflating: //content/history/Jessore.txt
#   inflating: //content/history/Jiamusi.txt
#   inflating: //content/history/Jijiga.txt
#   inflating: //content/history/Jimma.txt
#   inflating: //content/history/Jinan.txt
#   inflating: //content/history/Jingdezhen.txt
#   inflating: //content/history/Jining.txt
#   inflating: //content/history/Jinzhou.txt
#   inflating: //content/history/Jiujiang.txt
#   inflating: //content/history/Jiuzhaigou.txt
#   inflating: //content/history/Jixi.txt
#   inflating: //content/history/Jodhpur.txt
#   inflating: //content/history/Joenkoeping.txt
#   inflating: //content/history/Joensuu.txt
#   inflating: //content/history/Johannesburg.txt
#   inflating: //content/history/Johor Bahru.txt
#   inflating: //content/history/Joinville.txt
#   inflating: //content/history/Jolo.txt
#   inflating: //content/history/Jos.txt
#   inflating: //content/history/Juba.txt
#   inflating: //content/history/Juiz de Fora.txt
#   inflating: //content/history/Jujuy.txt
#   inflating: //content/history/Juliaca.txt
#   inflating: //content/history/Juneau.txt
#   inflating: //content/history/Jyvaskyla.txt
#   inflating: //content/history/Kabul.txt
#   inflating: //content/history/Kaduna.txt
#   inflating: //content/history/Kagoshima.txt
#   inflating: //content/history/Kahramanmaras.txt
#   inflating: //content/history/Kajaani.txt
#   inflating: //content/history/Kalamata.txt
#   inflating: //content/history/Kalamazoo.txt
#   inflating: //content/history/Kalemie.txt
#   inflating: //content/history/Kalgoorlie.txt
#   inflating: //content/history/Kalibo.txt
#   inflating: //content/history/Kaliningrad.txt
#   inflating: //content/history/Kalispell.txt
#   inflating: //content/history/Kaltag.txt
#   inflating: //content/history/Kalymnos.txt
#   inflating: //content/history/Kamloops.txt
#   inflating: //content/history/Kamuela.txt
#   inflating: //content/history/Kananga.txt
#   inflating: //content/history/Kanazawa.txt
#   inflating: //content/history/Kandahar.txt
#   inflating: //content/history/Kangding.txt
#   inflating: //content/history/Kangiqsualujjuaq.txt
#   inflating: //content/history/Kangirsuk.txt
#   inflating: //content/history/Kanpur.txt
#   inflating: //content/history/Kaohsiung.txt
#   inflating: //content/history/Kapuskasing.txt
#   inflating: //content/history/Karachi.txt
#   inflating: //content/history/Karaganda.txt
#   inflating: //content/history/Karamay.txt
#   inflating: //content/history/Karlovy Vary.txt
#   inflating: //content/history/Karlstad.txt
#   inflating: //content/history/Karpathos.txt
#   inflating: //content/history/Karratha.txt
#   inflating: //content/history/Kars.txt
#   inflating: //content/history/Kasos.txt
#   inflating: //content/history/Kassel.txt
#   inflating: //content/history/Kastamonu.txt
#   inflating: //content/history/Kastelorizo.txt
#   inflating: //content/history/Kastoria.txt
#   inflating: //content/history/Kathmandu.txt
#   inflating: //content/history/Katowice.txt
#   inflating: //content/history/Kaunas.txt
#   inflating: //content/history/Kavala.txt
#   inflating: //content/history/Kavieng.txt
#   inflating: //content/history/Kawthoung.txt
#   inflating: //content/history/Kayseri.txt
#   inflating: //content/history/Kazan.txt
#   inflating: //content/history/Keflavik.txt
#   inflating: //content/history/Kegaska.txt
#   inflating: //content/history/Kelowna.txt
#   inflating: //content/history/Kemi.txt
#   inflating: //content/history/Kenai.txt
#   inflating: //content/history/Kendari.txt
#   inflating: //content/history/Kengtung.txt
#   inflating: //content/history/Kenora.txt
#   inflating: //content/history/Kerman.txt
#   inflating: //content/history/Ketapang.txt
#   inflating: //content/history/Ketchikan.txt
#   inflating: //content/history/Key West.txt
#   inflating: //content/history/Khabarovsk.txt
#   inflating: //content/history/Khajuraho.txt
#   inflating: //content/history/Khanty-Mansiysk.txt
#   inflating: //content/history/Kharkov.txt
#   inflating: //content/history/Khartoum.txt
#   inflating: //content/history/Khasab.txt
#   inflating: //content/history/Khorram Abad.txt
#   inflating: //content/history/Khoy.txt
#   inflating: //content/history/Khudzhand.txt
#   inflating: //content/history/Kiev.txt
#   inflating: //content/history/Kigali.txt
#   inflating: //content/history/Kindu.txt
#   inflating: //content/history/Kingstown.txt
#   inflating: //content/history/Kinmen.txt
#   inflating: //content/history/Kinshasa.txt
#   inflating: //content/history/Kirensk.txt
#   inflating: //content/history/Kiritimati.txt
#   inflating: //content/history/Kirkenes.txt
#   inflating: //content/history/Kirksville.txt
#   inflating: //content/history/Kirkwall.txt
#   inflating: //content/history/Kiruna.txt
#   inflating: //content/history/Kisangani.txt
#   inflating: //content/history/Kish Island.txt
#   inflating: //content/history/Kisumu.txt
#   inflating: //content/history/Kitakyushu.txt
#   inflating: //content/history/Kitale.txt
#   inflating: //content/history/Kithira.txt
#   inflating: //content/history/Kivalina.txt
#   inflating: //content/history/Klagenfurt.txt
#   inflating: //content/history/Klamath Falls.txt
#   inflating: //content/history/Klawock.txt
#   inflating: //content/history/Knoxville.txt
#   inflating: //content/history/Ko Samui.txt
#   inflating: //content/history/Kobe.txt
#   inflating: //content/history/Kochi.txt
#   inflating: //content/history/Koggala.txt
#   inflating: //content/history/Kokshetau.txt
#   inflating: //content/history/Kolkata.txt
#   inflating: //content/history/Kone.txt
#   inflating: //content/history/Kongiganak.txt
#   inflating: //content/history/Konya.txt
#   inflating: //content/history/Korla.txt
#   inflating: //content/history/Kos.txt
#   inflating: //content/history/Kosice.txt
#   inflating: //content/history/Kosrae.txt
#   inflating: //content/history/Kostanay.txt
#   inflating: //content/history/Kota Bahru.txt
#   inflating: //content/history/Kota Kinabalu.txt
#   inflating: //content/history/Kotzebue.txt
#   inflating: //content/history/Koumac.txt
#   inflating: //content/history/Kowanyama.txt
#   inflating: //content/history/Kozani.txt
#   inflating: //content/history/Krabi.txt
#   inflating: //content/history/Krakow.txt
#   inflating: //content/history/Kralendijk.txt
#   inflating: //content/history/Krasnodar.txt
#   inflating: //content/history/Krasnoyarsk.txt
#   inflating: //content/history/Kristiansand.txt
#   inflating: //content/history/Kristianstad.txt
#   inflating: //content/history/Kristiansund.txt
#   inflating: //content/history/Kuala Lumpur.txt
#   inflating: //content/history/Kuala Terengganu.txt
#   inflating: //content/history/Kuantan.txt
#   inflating: //content/history/Kuching.txt
#   inflating: //content/history/Kudat.txt
#   inflating: //content/history/Kufra.txt
#   inflating: //content/history/Kuito.txt
#   inflating: //content/history/Kulyab.txt
#   inflating: //content/history/Kumamoto.txt
#   inflating: //content/history/Kumasi.txt
#   inflating: //content/history/Kumejima.txt
#   inflating: //content/history/Kunming.txt
#   inflating: //content/history/Kunsan.txt
#   inflating: //content/history/Kununurra.txt
#   inflating: //content/history/Kuopio.txt
#   inflating: //content/history/Kupang.txt
#   inflating: //content/history/Kuqa.txt
#   inflating: //content/history/Kuressaare.txt
#   inflating: //content/history/Kursk.txt
#   inflating: //content/history/Kushiro.txt
#   inflating: //content/history/Kutahya.txt
#   inflating: //content/history/Kutaisi.txt
#   inflating: //content/history/Kuujjuarapik.txt
#   inflating: //content/history/Kuusamo.txt
#   inflating: //content/history/Kuwait.txt
#   inflating: //content/history/Kwajalein.txt
#   inflating: //content/history/Kwangju.txt
#   inflating: //content/history/Kyaukpyu.txt
#   inflating: //content/history/Kyzyl.txt
#   inflating: //content/history/Kzyl-Orda.txt
#   inflating: //content/history/La Ceiba.txt
#   inflating: //content/history/La Coruna.txt
#   inflating: //content/history/La Crosse.txt
#   inflating: //content/history/La Paz.txt
#   inflating: //content/history/La Rioja.txt
#   inflating: //content/history/La Rochelle.txt
#   inflating: //content/history/La Tabatière.txt
#   inflating: //content/history/Laage.txt
#   inflating: //content/history/Labuan.txt
#   inflating: //content/history/Lagos.txt
#   inflating: //content/history/Lahad Datu.txt
#   inflating: //content/history/Lahore.txt
#   inflating: //content/history/Lalibella.txt
#   inflating: //content/history/Lamezia.txt
#   inflating: //content/history/Lampang.txt
#   inflating: //content/history/Lampedusa.txt
#   inflating: //content/history/Lamu.txt
#   inflating: //content/history/Lanai.txt
#   inflating: //content/history/Land's End.txt
#   inflating: //content/history/Langkawi.txt
#   inflating: //content/history/Lankaran.txt
#   inflating: //content/history/Lannion.txt
#   inflating: //content/history/Lansdowne House.txt
#   inflating: //content/history/Lansing.txt
#   inflating: //content/history/Lanzhou.txt
#   inflating: //content/history/Laoag.txt
#   inflating: //content/history/Lappeenranta.txt
#   inflating: //content/history/Larnaca.txt
#   inflating: //content/history/Larsen Bay.txt
#   inflating: //content/history/Las Vegas.txt
#   inflating: //content/history/Lawas.txt
#   inflating: //content/history/Le Havre.txt
#   inflating: //content/history/Lebanon.txt
#   inflating: //content/history/Leeds.txt
#   inflating: //content/history/Leh.txt
#   inflating: //content/history/Leipzig.txt
#   inflating: //content/history/Lensk.txt
#   inflating: //content/history/Leros.txt
#   inflating: //content/history/Lethbridge.txt
#   inflating: //content/history/Lhasa.txt
#   inflating: //content/history/Liberia.txt
#   inflating: //content/history/Libreville.txt
#   inflating: //content/history/Lichinga.txt
#   inflating: //content/history/Liege.txt
#   inflating: //content/history/Lifou.txt
#   inflating: //content/history/Lihue.txt
#   inflating: //content/history/Lijiang.txt
#   inflating: //content/history/Lille.txt
#   inflating: //content/history/Lilongwe.txt
#   inflating: //content/history/Lima.txt
#   inflating: //content/history/Limbang.txt
#   inflating: //content/history/Limnos.txt
#   inflating: //content/history/Limoges.txt
#   inflating: //content/history/Lincang.txt
#   inflating: //content/history/Linkoeping.txt
#   inflating: //content/history/Linyi.txt
#   inflating: //content/history/Linz.txt
#   inflating: //content/history/Lisbon.txt
#   inflating: //content/history/Little Cayman.txt
#   inflating: //content/history/Little Rock.txt
#   inflating: //content/history/Liuzhou.txt
#   inflating: //content/history/Liverpool.txt
#   inflating: //content/history/Ljubljana.txt
#   inflating: //content/history/Lleida.txt
#   inflating: //content/history/Lloydminster.txt
#   inflating: //content/history/Lodja.txt
#   inflating: //content/history/Lodwar.txt
#   inflating: //content/history/Lokichoggio.txt
#   inflating: //content/history/Lome.txt
#   inflating: //content/history/London.txt
#   inflating: //content/history/Londonderry.txt
#   inflating: //content/history/Long Beach.txt
#   inflating: //content/history/Longreach.txt
#   inflating: //content/history/Longyan.txt
#   inflating: //content/history/Lord Howe Island.txt
#   inflating: //content/history/Lorient.txt
#   inflating: //content/history/Los Angeles.txt
#   inflating: //content/history/Los Mochis.txt
#   inflating: //content/history/Louisville.txt
#   inflating: //content/history/Luanda.txt
#   inflating: //content/history/Luang Namtha.txt
#   inflating: //content/history/Luang Prabang.txt
#   inflating: //content/history/Lubango.txt
#   inflating: //content/history/Lubbock.txt
#   inflating: //content/history/Lublin.txt
#   inflating: //content/history/Lucknow.txt
#   inflating: //content/history/Luderitz.txt
#   inflating: //content/history/Luebeck.txt
#   inflating: //content/history/Lugano.txt
#   inflating: //content/history/Lulea.txt
#   inflating: //content/history/Luoyang.txt
#   inflating: //content/history/Lusaka.txt
#   inflating: //content/history/Lutselk'e.txt
#   inflating: //content/history/Luxemburg.txt
#   inflating: //content/history/Luxor.txt
#   inflating: //content/history/Luzhou.txt
#   inflating: //content/history/Lvov.txt
#   inflating: //content/history/Lycksele.txt
#   inflating: //content/history/Lyon.txt
#   inflating: //content/history/Maastricht.txt
#   inflating: //content/history/Macapa.txt
#   inflating: //content/history/Macau.txt
#   inflating: //content/history/Maceio.txt
#   inflating: //content/history/Madang.txt
#   inflating: //content/history/Madinah.txt
#   inflating: //content/history/Madras.txt
#   inflating: //content/history/Madrid.txt
#   inflating: //content/history/Madurai.txt
#   inflating: //content/history/Mae Hong Son.txt
#   inflating: //content/history/Magadan.txt
#   inflating: //content/history/Mahajanga.txt
#   inflating: //content/history/Majuro.txt
#   inflating: //content/history/Makemo.txt
#   inflating: //content/history/Makhachkala.txt
#   inflating: //content/history/Makkovik.txt
# ...
#   inflating: //content/history/Sogndal.txt
#   inflating: //content/history/Sohag.txt
#   inflating: //content/history/Solo City.txt
#   inflating: //content/history/Sorong.txt
#   inflating: //content/history/South Bend.txt
#   inflating: //content/history/South Caicos.txt
#   inflating: //content/history/Southampton.txt
#   inflating: //content/history/Southend.txt
#   inflating: //content/history/Spanish Town.txt
#   inflating: //content/history/Spokane.txt
#   inflating: //content/history/Srinagar.txt
#   inflating: //content/history/St George.txt
#   inflating: //content/history/St-Etienne.txt
#   inflating: //content/history/St. Augustine Airport.txt
#   inflating: //content/history/St. Louis.txt
#   inflating: //content/history/St. Petersburg.txt
#   inflating: //content/history/Stavanger.txt
#   inflating: //content/history/Stavropol.txt
#   inflating: //content/history/Stockholm.txt
#   inflating: //content/history/Stord.txt
#   inflating: //content/history/Stornoway.txt
#   inflating: //content/history/Strasbourg.txt
#   inflating: //content/history/Stronsay.txt
#   inflating: //content/history/Stuttgart.txt
#   inflating: //content/history/Sucre.txt
#   inflating: //content/history/Sukkur.txt
#   inflating: //content/history/Sulaymaniyah.txt
#   inflating: //content/history/Sundsvall.txt
#   inflating: //content/history/Sunyani.txt
#   inflating: //content/history/Surabaya.txt
#   inflating: //content/history/Surat Thani.txt
#   inflating: //content/history/Surat.txt
#   inflating: //content/history/Surgut.txt
#   inflating: //content/history/Svalbard.txt
#   inflating: //content/history/Svolvær.txt
#   inflating: //content/history/Sydney.txt
#   inflating: //content/history/Syktyvkar.txt
#   inflating: //content/history/Syros Island.txt
#   inflating: //content/history/Szczecin.txt
#   inflating: //content/history/Tabatinga.txt
#   inflating: //content/history/Tabriz.txt
#   inflating: //content/history/Tabubil.txt
#   inflating: //content/history/Tacheng.txt
#   inflating: //content/history/Tachilek.txt
#   inflating: //content/history/Tacloban.txt
#   inflating: //content/history/Tacna.txt
#   inflating: //content/history/Taegu.txt
#   inflating: //content/history/Taganrog.txt
#   inflating: //content/history/Tagbilaran.txt
#   inflating: //content/history/Taichung.txt
#   inflating: //content/history/Taif.txt
#   inflating: //content/history/Tainan.txt
#   inflating: //content/history/Taipei.txt
#   inflating: //content/history/Taiyuan.txt
#   inflating: //content/history/Taiz.txt
#   inflating: //content/history/Takamatsu.txt
#   inflating: //content/history/Takaroa.txt
#   inflating: //content/history/Takoradi.txt
#   inflating: //content/history/Tallahassee.txt
#   inflating: //content/history/Tamanrasset.txt
#   inflating: //content/history/Tambow.txt
#   inflating: //content/history/Tampa.txt
#   inflating: //content/history/Tampere.txt
#   inflating: //content/history/Tampico.txt
#   inflating: //content/history/Tanger.txt
#   inflating: //content/history/Tanjung Pinang.txt
#   inflating: //content/history/Tapachula.txt
#   inflating: //content/history/Tarapoto.txt
#   inflating: //content/history/Tarawa.txt
#   inflating: //content/history/Tarbes.txt
#   inflating: //content/history/Taree.txt
#   inflating: //content/history/Tarija.txt
#   inflating: //content/history/Tarko-Sale.txt
#   inflating: //content/history/Tartu.txt
#   inflating: //content/history/Tashkent.txt
#   inflating: //content/history/Tasiujaq.txt
#   inflating: //content/history/Tatalina.txt
#   inflating: //content/history/Taupo.txt
#   inflating: //content/history/Tauranga.txt
#   inflating: //content/history/Tawau.txt
#   inflating: //content/history/Tbilisi.txt
#   inflating: //content/history/Tebessa.txt
#   inflating: //content/history/Teesside.txt
#   inflating: //content/history/Tefe.txt
#   inflating: //content/history/Tegucigalpa.txt
#   inflating: //content/history/Teheran.txt
#   inflating: //content/history/Tehran.txt
#   inflating: //content/history/Tel-aviv.txt
#   inflating: //content/history/Temuco.txt
#   inflating: //content/history/Tenerife.txt
#   inflating: //content/history/Tengchong.txt
#   inflating: //content/history/Termez.txt
#   inflating: //content/history/Ternate.txt
#   inflating: //content/history/Teterboro.txt
#   inflating: //content/history/Tetouan.txt
#   inflating: //content/history/Texarkana.txt
#   inflating: //content/history/Thargomindah.txt
#   inflating: //content/history/The Pas.txt
#   inflating: //content/history/Thessaloniki.txt
#   inflating: //content/history/Thief River Falls.txt
#   inflating: //content/history/Thimphu.txt
#   inflating: //content/history/Thira.txt
#   inflating: //content/history/Thunder Bay.txt
#   inflating: //content/history/Tianjin.txt
#   inflating: //content/history/Tiaret.txt
#   inflating: //content/history/Tijuana.txt
#   inflating: //content/history/Tikehau.txt
#   inflating: //content/history/Tiksi.txt
#   inflating: //content/history/Timaru.txt
#   inflating: //content/history/Timisoara.txt
#   inflating: //content/history/Timmins.txt
#   inflating: //content/history/Tin City.txt
#   inflating: //content/history/Tirana.txt
#   inflating: //content/history/Tiree.txt
#   inflating: //content/history/Tirgu Mures.txt
#   inflating: //content/history/Tiruchirappalli.txt
#   inflating: //content/history/Tivat.txt
#   inflating: //content/history/Tlemcen.txt
#   inflating: //content/history/Toamasina.txt
#   inflating: //content/history/Tobruk.txt
#   inflating: //content/history/Toksook Bay.txt
#   inflating: //content/history/Tokushima.txt
#   inflating: //content/history/Tokyo.txt
#   inflating: //content/history/Tolagnaro.txt
#   inflating: //content/history/Toliara.txt
#   inflating: //content/history/Toluca.txt
#   inflating: //content/history/Tomsk.txt
#   inflating: //content/history/Tongatapu.txt
#   inflating: //content/history/Tongliao.txt
#   inflating: //content/history/Tongren.txt
#   inflating: //content/history/Toowoomba.txt
#   inflating: //content/history/Topeka.txt
#   inflating: //content/history/Torino.txt
#   inflating: //content/history/Toronto.txt
#   inflating: //content/history/Torreon.txt
#   inflating: //content/history/Tortola.txt
#   inflating: //content/history/Touggourt.txt
#   inflating: //content/history/Toulouse.txt
#   inflating: //content/history/Tours.txt
#   inflating: //content/history/Townsville.txt
#   inflating: //content/history/Tozeur.txt
#   inflating: //content/history/Trabzon.txt
#   inflating: //content/history/Trail.txt
#   inflating: //content/history/Trapani.txt
#   inflating: //content/history/Trat.txt
#   inflating: //content/history/Traverse City.txt
#   inflating: //content/history/Treasure Cay.txt
#   inflating: //content/history/Trelew.txt
#   inflating: //content/history/Treviso.txt
#   inflating: //content/history/Trinidad.txt
#   inflating: //content/history/Trivandrum.txt
#   inflating: //content/history/Trollhattan.txt
#   inflating: //content/history/Tromso.txt
#   inflating: //content/history/Trondheim.txt
#   inflating: //content/history/Tselinograd.txt
#   inflating: //content/history/Tshikapa.txt
#   inflating: //content/history/Tubuai.txt
#   inflating: //content/history/Tucson.txt
#   inflating: //content/history/Tucuman.txt
#   inflating: //content/history/Tuguegarao.txt
#   inflating: //content/history/Tuktoyaktuk.txt
#   inflating: //content/history/Tulcan.txt
#   inflating: //content/history/Tulita.txt
#   inflating: //content/history/Tulsa.txt
#   inflating: //content/history/Tunis.txt
#   inflating: //content/history/Turbat.txt
#   inflating: //content/history/Turku.txt
#   inflating: //content/history/Turukhansk.txt
#   inflating: //content/history/Tuxtla Gutierrez.txt
#   inflating: //content/history/Tyumen.txt
#   inflating: //content/history/Ua Huka.txt
#   inflating: //content/history/Ua Pou.txt
#   inflating: //content/history/Uberaba.txt
#   inflating: //content/history/Ubon Ratchathani.txt
#   inflating: //content/history/Udaipur.txt
#   inflating: //content/history/Udon Thani.txt
#   inflating: //content/history/Ufa.txt
#   inflating: //content/history/Ujung Pandang.txt
#   inflating: //content/history/Ukhta.txt
#   inflating: //content/history/Ulaangom.txt
#   inflating: //content/history/Ulan Bator.txt
#   inflating: //content/history/Uliastai.txt
#   inflating: //content/history/Ulsan.txt
#   inflating: //content/history/Uluru.txt
#   inflating: //content/history/Ulyanovsk.txt
#   inflating: //content/history/Umea.txt
#   inflating: //content/history/Umiujaq.txt
#   inflating: //content/history/Umtata.txt
#   inflating: //content/history/Unalakleet.txt
#   inflating: //content/history/Unalaska.txt
#   inflating: //content/history/Upernavik.txt
#   inflating: //content/history/Urgench.txt
#   inflating: //content/history/Uromiyeh.txt
#   inflating: //content/history/Uruapan.txt
#   inflating: //content/history/Urumqi.txt
#   inflating: //content/history/Ushuaia.txt
#   inflating: //content/history/Ust Kamenogorsk.txt
#   inflating: //content/history/Ust-Kut.txt
#   inflating: //content/history/Utila.txt
#   inflating: //content/history/Uzhgorod.txt
#   inflating: //content/history/Vaasa.txt
#   inflating: //content/history/Vagar.txt
#   inflating: //content/history/Vail.txt
#   inflating: //content/history/Val D'or.txt
#   inflating: //content/history/Valdivia.txt
#   inflating: //content/history/Valdosta.txt
#   inflating: //content/history/Valencia.txt
#   inflating: //content/history/Valera.txt
#   inflating: //content/history/Valladolid.txt
#   inflating: //content/history/Valledupar.txt
#   inflating: //content/history/Valparaiso.txt
#   inflating: //content/history/Van.txt
#   inflating: //content/history/Vancouver.txt
#   inflating: //content/history/Varadero.txt
#   inflating: //content/history/Varanasi.txt
#   inflating: //content/history/Vasteras.txt
#   inflating: //content/history/Vaxjo.txt
#   inflating: //content/history/Veliky Ustyug.txt
#   inflating: //content/history/Venetie.txt
#   inflating: //content/history/Venice.txt
#   inflating: //content/history/Victoria Falls.txt
#   inflating: //content/history/Viedma.txt
#   inflating: //content/history/Vienna.txt
#   inflating: //content/history/Vientiane.txt
#   inflating: //content/history/Vieques Island.txt
#   inflating: //content/history/Vigo.txt
#   inflating: //content/history/Vijayawada.txt
#   inflating: //content/history/Vilhelmina.txt
#   inflating: //content/history/Vilhena.txt
#   inflating: //content/history/Villahermosa.txt
#   inflating: //content/history/Villavicencio.txt
#   inflating: //content/history/Vilnius.txt
#   inflating: //content/history/Vinh.txt
#   inflating: //content/history/Vinnitsa.txt
#   inflating: //content/history/Visalia.txt
#   inflating: //content/history/Visby.txt
#   inflating: //content/history/Vishakhapatnam.txt
#   inflating: //content/history/Vladivostok.txt
#   inflating: //content/history/Volgograd.txt
#   inflating: //content/history/Vorkuta.txt
#   inflating: //content/history/Voronezh.txt
#   inflating: //content/history/Waco.txt
#   inflating: //content/history/Wagga Wagga.txt
#   inflating: //content/history/Waingapu.txt
#   inflating: //content/history/Wajir.txt
#   inflating: //content/history/Wakkanai.txt
#   inflating: //content/history/Wales.txt
#   inflating: //content/history/Walvis Bay.txt
#   inflating: //content/history/Wamena.txt
#   inflating: //content/history/Wanganui.txt
#   inflating: //content/history/Wanxian.txt
#   inflating: //content/history/Warsaw.txt
#   inflating: //content/history/Waskaganish.txt
#   inflating: //content/history/Waterford.txt
#   inflating: //content/history/Webequie.txt
#   inflating: //content/history/Weeze.txt
#   inflating: //content/history/Weifang.txt
#   inflating: //content/history/Weipa.txt
#   inflating: //content/history/Wekweeti.txt
#   inflating: //content/history/Wellington.txt
#   inflating: //content/history/Wemindji.txt
#   inflating: //content/history/Wenatchee.txt
#   inflating: //content/history/Wenzhou.txt
#   inflating: //content/history/West Palm Beach.txt
#   inflating: //content/history/Westray.txt
#   inflating: //content/history/Wewak.txt
#   inflating: //content/history/Weyers Cave.txt
#   inflating: //content/history/Whangarei.txt
#   inflating: //content/history/Whatì.txt
#   inflating: //content/history/Whitehorse.txt
#   inflating: //content/history/Whyalla.txt
#   inflating: //content/history/Wichita Falls.txt
#   inflating: //content/history/Willemstad.txt
#   inflating: //content/history/Windhoek.txt
#   inflating: //content/history/Windorah.txt
#   inflating: //content/history/Windsor Locks.txt
#   inflating: //content/history/Winnipeg.txt
#   inflating: //content/history/Wolf Point.txt
#   inflating: //content/history/Wonju.txt
#   inflating: //content/history/Wroclaw.txt
#   inflating: //content/history/Wuhai.txt
#   inflating: //content/history/Wuhan.txt
#   inflating: //content/history/Wuxi.txt
#   inflating: //content/history/Xi'an.txt
#   inflating: //content/history/Xiamen.txt
#   inflating: //content/history/Xiangfan.txt
#   inflating: //content/history/Xichang.txt
#   inflating: //content/history/Xilinhot.txt
#   inflating: //content/history/Xining.txt
#   inflating: //content/history/Xuzhou.txt
#   inflating: //content/history/Yakima.txt
#   inflating: //content/history/Yakutia.txt
#   inflating: //content/history/Yakutsk.txt
#   inflating: //content/history/Yan'an.txt
#   inflating: //content/history/Yancheng.txt
#   inflating: //content/history/Yangon.txt
#   inflating: //content/history/Yangzhou.txt
#   inflating: //content/history/Yanji.txt
#   inflating: //content/history/Yantai.txt
#   inflating: //content/history/Yaounde.txt
#   inflating: //content/history/Yap.txt
#   inflating: //content/history/Yaroslavl.txt
#   inflating: //content/history/Yasuj.txt
#   inflating: //content/history/Yazd.txt
#   inflating: //content/history/Yekaterinburg.txt
#   inflating: //content/history/Yellowknife.txt
#   inflating: //content/history/Yenbo.txt
#   inflating: //content/history/Yeosu.txt
#   inflating: //content/history/Yerevan.txt
#   inflating: //content/history/Yibin.txt
#   inflating: //content/history/Yichang.txt
#   inflating: //content/history/Yining.txt
#   inflating: //content/history/Yiwu.txt
#   inflating: //content/history/Yogyakarta.txt
#   inflating: //content/history/Yongzhou.txt
#   inflating: //content/history/Yopal.txt
#   inflating: //content/history/Youngstown.txt
#   inflating: //content/history/Yuncheng.txt
#   inflating: //content/history/Yuzhno-Kurilsk.txt
#   inflating: //content/history/Zacatecas.txt
#   inflating: //content/history/Zadar.txt
#   inflating: //content/history/Zagreb.txt
#   inflating: //content/history/Zahedan.txt
#   inflating: //content/history/Zakynthos.txt
#   inflating: //content/history/Zanzibar.txt
#   inflating: //content/history/Zaporozhye.txt
#   inflating: //content/history/Zaragoza.txt
#   inflating: //content/history/Zarzaitine.txt
#   inflating: //content/history/Zhangjiakou.txt
#   inflating: //content/history/Zhangye.txt
#   inflating: //content/history/Zhanjiang.txt
#   inflating: //content/history/Zhaotong.txt
#   inflating: //content/history/Zhengzhou.txt
#   inflating: //content/history/Zhezkazgan.txt
#   inflating: //content/history/Zhob.txt
#   inflating: //content/history/Zhongwei.txt
#   inflating: //content/history/Zhoushan.txt
#   inflating: //content/history/Zhuhai.txt
#   inflating: //content/history/Ziguinchor.txt
#   inflating: //content/history/Zihuatanejo.txt
#   inflating: //content/history/Zonguldak.txt
#   inflating: //content/history/Zouerat.txt
#   inflating: //content/history/Zunyi.txt
#   inflating: //content/history/Zurich.txt
#   inflating: //content/history/Zweibruecken.txt
#   inflating: //content/history/Ängelholm.txt
#   inflating: //content/history/Çorlu.txt
#   inflating: //content/history/Île des Pins.txt
#   inflating: //content/history/Östersund.txt

# %%
import pickle
with open('graph_with_content.pickle', 'rb') as f:
   G_loaded = pickle.load(f)
print(len(G_loaded.edges()))
# Out:
# 26808

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import tensorflow as tf
import polars as pl
import os
import pandas as pd
import numpy as np

# %%
def get_transformers_word_embeddings(model: AutoModel):
    return model.embeddings.word_embeddings.weight.data.to("cpu").numpy()

def generate_embeddings_with_transformers(
    model: AutoModel,
    tokenizer: AutoTokenizer,
    text_list: list[str],
    batch_size: int = 8,
    device: str = None,
    disable_tqdm: bool = False,
) -> torch.Tensor:
    """
    Generates embeddings for a list of texts using a pre-trained transformer model.

    Args:
        model_name (str): The name of the pre-trained transformer model to use.
        text_list (list of str): A list of texts to generate embeddings for.
        batch_size (int): The batch size to use for generating embeddings. Defaults to 8.
        device (str): The device to use for generating embeddings (e.g., "cpu", "cuda").
            If None, defaults to the first available GPU or CPU.

    Returns:
        embeddings (torch.Tensor): A tensor containing the embeddings for the input texts.
            The shape of the tensor is (num_texts, embedding_dim), where num_texts is the number
            of input texts and embedding_dim is the dimensionality of the embeddings produced by
            the pre-trained model.

    Examples:
    >>> model_name = "bert-base-uncased"
    >>> text_list = ["hello world", "how are you"]
    >>> batch_size = 2
    >>> device = "cpu"
    >>> model = AutoModel.from_pretrained(model_name)
    >>> tokenizer = AutoTokenizer.from_pretrained(model_name)
    >>> embeddings_tensor = generate_embeddings_with_transformers(model, tokenizer, text_list, batch_size, device)
    >>> print(embeddings_tensor)
        tensor([[-0.0243,  0.1144,  0.0830,  ..., -0.2666,  0.1662,  0.1519],
                [ 0.0827,  0.0877, -0.0688,  ..., -0.4381,  0.0462, -0.1446]])
    >>> print(embeddings_tensor.shape)
        torch.Size([2, 768])
    """
    device = get_torch_device(use_gpu=True) if device is None else device
    model = model.to(device)

    tokenized_text = tokenizer(
        text_list, padding=True, truncation=True, return_tensors="pt"
    )
    feature_names = list(tokenized_text)

    dataset = TensorDataset(
        tokenized_text["input_ids"], tokenized_text["attention_mask"]
    )
    dataloader = DataLoader(dataset, batch_size=batch_size)
    embeddings = []
    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Encoding", disable=disable_tqdm):
            inputs = {feat: t.to(device) for feat, t in zip(feature_names, batch)}
            outputs = model(
                **inputs,
                output_hidden_states=True,
            )
            embeddings.append(outputs.last_hidden_state[:, 0, :].squeeze(dim=1))
    return torch.vstack(embeddings)


def convert_text2encoding_with_transformers(
    df: pl.DataFrame,
    tokenizer: AutoTokenizer,
    column: str,
    max_length: int = 512,
) -> pl.DataFrame:
    """Converts text in a specified DataFrame column to tokens using a provided tokenizer.
    Args:
        df (pl.DataFrame): The input DataFrame containing the text column.
        tokenizer (AutoTokenizer): The tokenizer to use for encoding the text. (from transformers import AutoTokenizer)
        column (str): The name of the column containing the text.
        max_length (int, optional): The maximum length of the encoded tokens. Defaults to None.
    Returns:
        pl.DataFrame: A new DataFrame with an additional column containing the encoded tokens.
    Example:
    >>> from transformers import AutoTokenizer
    >>> import polars as pl
    >>> df = pl.DataFrame({
            'text': ['This is a test.', 'Another test string.', 'Yet another one.']
        })
    >>> tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
    >>> encoded_df, new_column = convert_text2encoding_with_transformers(df, tokenizer, 'text', max_length=20)
    >>> print(encoded_df)
        shape: (3, 2)
        ┌──────────────────────┬───────────────────────────────┐
        │ text                 ┆ text_encode_bert-base-uncased │
        │ ---                  ┆ ---                           │
        │ str                  ┆ list[i64]                     │
        ╞══════════════════════╪═══════════════════════════════╡
        │ This is a test.      ┆ [2023, 2003, … 0]             │
        │ Another test string. ┆ [2178, 3231, … 0]             │
        │ Yet another one.     ┆ [2664, 2178, … 0]             │
        └──────────────────────┴───────────────────────────────┘
    >>> print(new_column)
        text_encode_bert-base-uncased
    """
    text = df[column].to_list()
    # set columns
    new_column = f"{column}_encode_{tokenizer.name_or_path}"
    # If 'max_length' is provided then set it, else encode each string its original length
    padding = "max_length" if max_length else False
    encoded_tokens = tokenizer(
        text,
        add_special_tokens=False,
        padding=padding,
        max_length=max_length,
        truncation=True,
    )["input_ids"]
    return df.with_columns(pl.Series(new_column, encoded_tokens)), new_column

def concat_str_columns(df: pl.DataFrame, columns: list[str]) -> pl.DataFrame:
    """
    >>> df = pl.DataFrame(
            {
                "id": [1, 2, 3],
                "first_name": ["John", "Jane", "Alice"],
                "last_name": ["Doe", "Doe", "Smith"],
            }
        )
    >>> concatenated_df, concatenated_column_name = concat_str_columns(df, columns=['first_name', 'last_name'])
    >>> concatenated_df
        shape: (3, 4)
        ┌─────┬────────────┬───────────┬──────────────────────┐
        │ id  ┆ first_name ┆ last_name ┆ first_name-last_name │
        │ --- ┆ ---        ┆ ---       ┆ ---                  │
        │ i64 ┆ str        ┆ str       ┆ str                  │
        ╞═════╪════════════╪═══════════╪══════════════════════╡
        │ 1   ┆ John       ┆ Doe       ┆ John Doe             │
        │ 2   ┆ Jane       ┆ Doe       ┆ Jane Doe             │
        │ 3   ┆ Alice      ┆ Smith     ┆ Alice Smith          │
        └─────┴────────────┴───────────┴──────────────────────┘
    """
    concat_name = "-".join(columns)
    concat_columns = df.select(pl.concat_str(columns, separator=" ").alias(concat_name))
    return df.with_columns(concat_columns), concat_name

# %%
print(G_loaded.nodes())
# Out:
# ['Sochi', 'Kazan', 'Astrakhan', 'Mineralnye Vody', 'Chelyabinsk', 'Novosibirsk', 'Moscow', 'Taganrog', 'Belgorod', 'Kaliningrad', 'Baku', 'St. Petersburg', 'Yekaterinburg', 'Nizhnevartovsk', 'Novy Urengoy', 'Bratsk', 'Irkutsk', 'Kirensk', 'Bodaibo', 'Ust-Kut', 'Lensk', 'Yakutsk', 'Ayacucho', 'Lima', 'Cuzco', 'Puerto Maldonado', 'Huánuco', 'Iquitos', 'Pucallpa', 'Tarapoto', 'Abidjan', 'Ouagadougou', 'Accra', 'Bamako', 'Dakar', 'Cotonou', 'Lome', 'Niamey', 'Bogota', 'Guayaquil', 'Quito', 'Cali', 'Coca', 'Brindisi', 'Zurich', 'Bordeaux', 'Bristol', 'Geneva', 'Gran Canaria', 'Larnaca', 'Marsa Alam', 'Tenerife', 'Arvidsjaur', 'Lycksele', 'Stockholm', 'Gallivare', 'Halmstad', 'Joenkoeping', 'Karlstad', 'Mariehamn', 'Ornskoldsvik', 'Pori', 'Sandefjord', 'Visby', 'Vilhelmina', 'Vaxjo', 'Hemavan', 'Kruunupyy', 'Turku', 'Oslo', 'Larsen Bay', 'Manila', 'Butuan', 'Cotabato', 'Cagayan de Oro City', 'Dumaguete', 'Dubai', 'Romblon', 'Kalibo', 'Caticlan', 'Ozamis', 'Puerto Princesa', 'Roxas City', 'Sangley Point', 'Tuguegarao', 'Araguaina', 'Barreiras', 'Brasilia', 'Ribeirao Preto', 'Cascavel', 'Sao Paulo', 'Cuiaba', 'Goiania', 'Campo Grande', 'Dourados', 'Rio De Janeiro', 'Uberaba', 'Uberlandia', 'Belo Horizonte', 'Sao Jose Do Rio Preto', 'Chicago', 'St. Louis', 'Ketchikan', 'Lagos', 'Monrovia', 'Barcelona', 'Banjul', 'Freetown', 'Conakry', 'Bissau', 'Douala', 'London', 'Akulivik', 'Ivujivik', 'Puvirnituq', 'Kangiqsualujjuaq', 'La Grande Riviere', 'Kuujjuarapik', 'Montreal', 'Inukjuak', 'Sanikiluaq', 'Umiujaq', 'Rouyn', 'Salluit', 'Kangirsuk', 'Quaqtaq', 'Schefferville', 'Quebec', 'Wabush', 'Tasiujaq', 'Kangiqsujuaq', 'Djibouti', 'Jeddah', 'Mogadishu', 'Nairobi', 'Bangkok', 'Singapore', 'Haikou', 'Hangzhou', 'Hong Kong', 'Phuket', 'Osaka', 'Taipei', 'Kuala Lumpur', 'Penang', 'Perth', 'Siem-reap', 'Yangon', 'Ho Chi Minh City', 'Shantou', 'Altenrhein', 'Dresden', 'Duesseldorf', 'Friedrichshafen', 'Munich', 'Hamburg', 'Olbia', 'Berlin', 'Zadar', 'Memmingen', 'Naples', 'Graz', 'Salzburg', 'Atlanta', 'Meridian', 'Muscle Shoals', 'Fort Lauderdale', 'West Palm Beach', 'Key West', 'Fort Myers', 'Tampa', 'Great Exuma', 'Marsh Harbor', 'Treasure Cay', 'Jacksonville', 'Pensacola', 'Tallahassee', 'Amsterdam', 'Tanger', 'Casablanca', 'Bergamo', 'Bologna', 'Brussels', 'Cologne', 'Cuneo', 'Lyon', 'Montpellier', 'Istanbul', 'Toulouse', 'Treviso', 'Fes', 'Palma de Mallorca', 'Paraguana', 'Maracaibo', 'Kralendijk', 'Willemstad', 'Bukhara', 'Fergana', 'Namangan', 'Navoi', 'Samarkand', 'Tivat', 'Antigua', 'Cayenne', 'Santo Domingo', 'Dominica', 'Castries', 'Beihai', "Xi'an", 'Guangzhou', 'Chongqing', 'Chengdu', 'Saipan', 'Zhengzhou', 'Changchun', 'Harbin', 'Kunming', 'Urumqi', 'Nanjing', 'Jinan', 'Tianjin', 'Changzhou', 'Dalian', 'Dayong', 'Nanchang', 'Lanzhou', 'Lijiang', 'Lhasa', 'Ninbo', 'Nanning', 'Beijing', 'Shanghai', 'Panzhihua', 'Sydney', 'Sanya', 'Shenzhen', 'Taiyuan', 'Wuhan', 'Wuxi', 'Xining', 'Yichang', 'Zhanjiang', 'Fuzhou', 'Shenyang', 'Wenzhou', 'Xiamen', 'Daocheng', 'Dongsheng', 'Handan', 'Hohhot', 'Hefei', 'Seoul', 'Jiuzhaigou', 'Ganzhou', 'Guiyang', 'Nyingchi', 'Melbourne', 'Shijiazhuang', 'Qingdao', 'Wanxian', 'Xichang', 'Xuzhou', 'Yangzhou', 'Zhuhai', 'Datong', 'Dunhuang', 'Manzhouli', 'Quanzhou', 'Guilin', 'Mianyang', 'Linyi', 'Zhongwei', 'Vancouver', 'Yibin', 'Las Vegas', 'Los Angeles', 'Cairo', 'Tel-aviv', 'Tatalina', 'Nukus', 'Tyumen', 'Ufa', 'Nadym', 'Ukhta', 'Dhaka', 'Barisal', 'Kolkata', 'Chittagong', 'Muscat', "Cox's Bazar", 'Jessore', 'Kathmandu', 'Rajshahi', 'Grise Fiord', 'Dallas-Fort Worth', 'Buenos Aires', 'Miami', 'Punta Cana', 'Edmonton', 'Whitehorse', 'Kelowna', 'Ottawa', 'Yellowknife', 'Calgary', 'Acapulco', 'Mexico City', 'Toluca', 'Aguascalientes', 'Ciudad Obregon', 'Ciudad Juarez', 'Ciudad Del Carmen', 'Campeche', 'Chetumal', 'Culiacan', 'Cancun', 'Monterrey', 'Cozumel', 'Guadalajara', 'San Antonio', 'San Jose Del Cabo', 'Tijuana', 'Guatemala City', 'Havana', 'Hermosillo', 'Huatulco', 'La Paz', 'Mazatlan', 'Oaxaca', 'Pale ...

# %%
#go through every file in history folder
text_df = pl.DataFrame({"node": pl.Series([], dtype=pl.Utf8), "content": pl.Series([], dtype=pl.Utf8)})

for filename in os.listdir('history'):
    #save to dataframe node name in one column and content in another
    filename_wo_txt = filename.split('.')[0]
    #check if node is in graph
    if filename_wo_txt in G_loaded.nodes():
        with open(os.path.join('history', filename), 'r', encoding='utf-8') as file:
            content = file.read()
        #add content to dataframe
        new_row = pl.DataFrame({"node": [filename_wo_txt], "content": [content]})
        text_df = pl.concat([text_df, new_row], how="vertical", rechunk=True)

# %%
#remove empty content
text_df = text_df.filter(pl.col("content") != "")

# %%
text_df
# Out:
# shape: (1_949, 2)
# ┌─────────────────┬─────────────────────────────────┐
# │ node            ┆ content                         │
# │ ---             ┆ ---                             │
# │ str             ┆ str                             │
# ╞═════════════════╪═════════════════════════════════╡
# │ Whitehorse      ┆ Archaeological research south … │
# │ Dijon           ┆ The earliest archaeological fi… │
# │ Bhubaneswar     ┆ Bhubaneswar stands near the ru… │
# │ Paris           ┆ ===Origins===                   │
# │                 ┆                                 │
# │                 ┆ The ''Parisii (…                │
# │ Dire Dawa       ┆ === Origins ===                 │
# │                 ┆                                 │
# │                 ┆                                 │
# │                 ┆ The region w…                   │
# │ …               ┆ …                               │
# │ Kenora          ┆ Kenora is situated on the trad… │
# │ Lansdowne House ┆ It was designed by Robert Adam… │
# │ Kostanay        ┆ Kostanay was founded by Russia… │
# │ Chumphon        ┆ Chumphon volunteers fought inv… │
# │ Tanjung Pinang  ┆ The name ''Tanjungpinang'' is … │
# └─────────────────┴─────────────────────────────────┘

# %% [markdown]
# # Transformers

# %%
TRANSFORMER_MODEL_NAME = "dslim/bert-base-NER"
TEXT_COLUMNS_TO_USE = ['content']

# LOAD HUGGINGFACE:
transformer_model = AutoModel.from_pretrained(TRANSFORMER_MODEL_NAME)
transformer_tokenizer = AutoTokenizer.from_pretrained(TRANSFORMER_MODEL_NAME)

# We'll init the word embeddings using the
word2vec_embedding = get_transformers_word_embeddings(transformer_model)
#
df_articles, token_col_title = convert_text2encoding_with_transformers(text_df, transformer_tokenizer, TEXT_COLUMNS_TO_USE[0])
# Out:
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
df_articles
# Out:
# shape: (1_949, 3)
# ┌─────────────────┬─────────────────────────────────┬─────────────────────────────────┐
# │ node            ┆ content                         ┆ content_encode_dslim/bert-base… │
# │ ---             ┆ ---                             ┆ ---                             │
# │ str             ┆ str                             ┆ list[i64]                       │
# ╞═════════════════╪═════════════════════════════════╪═════════════════════════════════╡
# │ Whitehorse      ┆ Archaeological research south … ┆ [17249, 1844, … 3441]           │
# │ Dijon           ┆ The earliest archaeological fi… ┆ [1109, 5041, … 118]             │
# │ Bhubaneswar     ┆ Bhubaneswar stands near the ru… ┆ [139, 6583, … 0]                │
# │ Paris           ┆ ===Origins===                   ┆ [134, 134, … 2226]              │
# │                 ┆                                 ┆                                 │
# │                 ┆ The ''Parisii (…                ┆                                 │
# │ Dire Dawa       ┆ === Origins ===                 ┆ [134, 134, … 1113]              │
# │                 ┆                                 ┆                                 │
# │                 ┆                                 ┆                                 │
# │                 ┆ The region w…                   ┆                                 │
# │ …               ┆ …                               ┆ …                               │
# │ Kenora          ┆ Kenora is situated on the trad… ┆ [5928, 6533, … 15171]           │
# │ Lansdowne House ┆ It was designed by Robert Adam… ┆ [1135, 1108, … 0]               │
# │ Kostanay        ┆ Kostanay was founded by Russia… ┆ [19892, 13946, … 0]             │
# │ Chumphon        ┆ Chumphon volunteers fought inv… ┆ [17144, 8223, … 0]              │
# │ Tanjung Pinang  ┆ The name ''Tanjungpinang'' is … ┆ [1109, 1271, … 1125]            │
# └─────────────────┴─────────────────────────────────┴─────────────────────────────────┘

# %%
from sklearn.metrics.pairwise import cosine_similarity

cities = df_articles['node'].to_list()
embeddings = np.vstack(df_articles[token_col_title].to_list())

# Compute the cosine similarity matrix
cosine_similarities = cosine_similarity(embeddings)

# Put in a dataframe
cosine_similarities_df = pd.DataFrame(cosine_similarities, index=cities, columns=cities)

# %%
cosine_similarities_df
# Out:
#                  Whitehorse     Dijon  Bhubaneswar     Paris  Dire Dawa  \
# Whitehorse         1.000000  0.349144     0.383136  0.264592   0.330431
# Dijon              0.349144  1.000000     0.376943  0.291911   0.306575
# Bhubaneswar        0.383136  0.376943     1.000000  0.303877   0.340351
# Paris              0.264592  0.291911     0.303877  1.000000   0.339606
# Dire Dawa          0.330431  0.306575     0.340351  0.339606   1.000000
# ...                     ...       ...          ...       ...        ...
# Kenora             0.302376  0.319758     0.319841  0.300580   0.300686
# Lansdowne House    0.363818  0.283245     0.317646  0.225961   0.363167
# Kostanay           0.197144  0.160578     0.231299  0.162952   0.162612
# Chumphon           0.140861  0.126081     0.140500  0.109445   0.133766
# Tanjung Pinang     0.343259  0.352706     0.286573  0.309230   0.319903
#
#                  Ubon Ratchathani  Rahim Yar Khan  Biratnagar  Point Barrow  \
# Whitehorse               0.259299        0.233734    0.306238      0.258541
# Dijon                    0.235414        0.241915    0.306068      0.252315
# Bhubaneswar              0.276071        0.309578    0.274914      0.316195
# Paris                    0.307150        0.180976    0.228241      0.180983
# Dire Dawa                0.270343        0.234997    0.309308      0.295222
# ...                           ...             ...         ...           ...
# Kenora                   0.224892        0.273725    0.268068      0.184177
# Lansdowne House          0.254992        0.325998    0.229018      0.231332
# Kostanay                 0.142766        0.249575    0.178729      0.251510
# Chumphon                 0.070953        0.072069    0.089139      0.226743
# Tanjung Pinang           0.264450        0.234397    0.338602      0.164441
#
#                  Mexico City  ...  Libreville  Ornskoldsvik    Bratsk  \
# Whitehorse          0.324077  ...    0.296412      0.244054  0.324596
# Dijon               0.321217  ...    0.312380      0.207978  0.341501
# Bhubaneswar         0.290207  ...    0.319912      0.259656  0.322451
# Paris               0.283880  ...    0.356542      0.197672  0.307249
# Dire Dawa           0.331237  ...    0.327233      0.187493  0.320525
# ...                      ...  ...         ...           ...       ...
# Kenora              0.282594  ...    0.331843      0.141383  0.271687
# Lansdowne House     0.291527  ...    0.304751      0.145972  0.272815
# Kostanay            0.147616  ...    0.178037      0.398178  0.213518
# Chumphon            0.091669  ...    0.114096      0.256086  0.119183
# Tanjung Pinang      0.266038  ...    0.316601      0.160310  0.324194
#
#                    Bilbao    Koumac    Kenora  Lansdowne House  Kostanay  \
# Whitehorse       0.308164  0.170247  0.302376         0.363818  0.197144
# Dijon            0.338653  0.122056  0.319758         0.283245  0.160578
# Bhubaneswar      0.298039  0.200947  0.319841         0.317646  0.231299
# Paris            0.290608  0.124168  0.300580         0.225961  0.162952
# Dire Dawa        0.293305  0.203748  0.300686         0.363167  0.162612
# ...                   ...       ...       ...              ...       ...
# Kenora           0.296401  0.171277  1.000000         0.237499  0.176831
# Lansdowne House  0.274801  0.154894  0.237499         1.000000  0.114969
# Kostanay         0.135462  0.357059  0.176831         0.114969  1.000000
# Chumphon         0.084535  0.228168  0.123299         0.070754  0.365263
# Tanjung Pinang   0.321563  0.130511  0.348192         0.356473  0.151600
#
#                  Chumphon  Tanjung Pinang
# Whitehorse       0.140861        0.343259
# Dijon            0.126081        0.352706
# Bhubaneswar      0.140500        0.286573
# Paris            0.109445        0.309230
# Dire Dawa        0.133766        0.319903
# ...                   ...             ...
# Kenora           0.123299        0.348192
# Lansdowne House  0.070754        0.356473
# Kostanay         0.365263        0.151600
# Chumphon         1.000000        0.118029
# Tanjung Pinang   0.118029        1.000000
#
# [1949 rows x 1949 columns]

# %%
cosine_similarities_df.describe()
# Out:
#         Whitehorse        Dijon  Bhubaneswar        Paris    Dire Dawa  \
# count  1949.000000  1949.000000  1949.000000  1949.000000  1949.000000
# mean      0.300354     0.289570     0.311415     0.268011     0.294690
# std       0.064225     0.066840     0.055295     0.065559     0.059751
# min       0.029049     0.041007     0.039328     0.016217     0.021416
# 25%       0.279873     0.266237     0.292557     0.241901     0.272635
# 50%       0.312522     0.305147     0.318826     0.282476     0.304235
# 75%       0.338395     0.330725     0.343076     0.309230     0.331022
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        Ubon Ratchathani  Rahim Yar Khan   Biratnagar  Point Barrow  \
# count       1949.000000     1949.000000  1949.000000   1949.000000
# mean           0.276346        0.258657     0.275132      0.246471
# std            0.057788        0.055164     0.062219      0.050289
# min            0.016678        0.021761     0.027876      0.039848
# 25%            0.254153        0.230649     0.250422      0.217522
# 50%            0.283788        0.259331     0.286512      0.244806
# 75%            0.310297        0.288326     0.313762      0.275328
# max            1.000000        1.000000     1.000000      1.000000
#
#        Mexico City  ...   Libreville  Ornskoldsvik       Bratsk       Bilbao  \
# count  1949.000000  ...  1949.000000   1949.000000  1949.000000  1949.000000
# mean      0.285902  ...     0.295703      0.217505     0.287073     0.295712
# std       0.072380  ...     0.063159      0.057003     0.060034     0.066034
# min       0.011483  ...     0.044207      0.043472     0.046004     0.018817
# 25%       0.259364  ...     0.271693      0.179703     0.262112     0.273058
# 50%       0.303904  ...     0.308199      0.207974     0.297970     0.310257
# 75%       0.333184  ...     0.336257      0.247034     0.325124     0.337097
# max       1.000000  ...     1.000000      1.000000     1.000000     1.000000
#
#             Koumac       Kenora  Lansdowne House     Kostanay     Chumphon  \
# count  1949.000000  1949.000000      1949.000000  1949.000000  1949.000000
# mean      0.182217     0.284660         0.273019     0.184710     0.123030
# std       0.062710     0.064128         0.068143     0.062062     0.069839
# min       0.019800     0.036923         0.017690     0.016937     0.004122
# 25%       0.141684     0.257233         0.254400     0.143171     0.078892
# 50%       0.171957     0.297033         0.286520     0.174400     0.108010
# 75%       0.208566     0.325981         0.314355     0.213600     0.143511
# max       1.000000     1.000000         1.000000     1.000000     1.000000
#
#        Tanjung Pinang
# count     1949.000000
# mean         0.292353
# std          0.069486
# min          0.031908
# 25%          0.271519
# 50%          0.308333
# 75%          0.335748
# max          1.000000
#
# [8 rows x 1949 columns]

# %%
text_df.filter(pl.col("node") == "Rennes")
# Out:
# shape: (0, 2)
# ┌──────┬─────────┐
# │ node ┆ content │
# │ ---  ┆ ---     │
# │ str  ┆ str     │
# ╞══════╪═════════╡
# └──────┴─────────┘

# %%
print("Mean: ", cosine_similarities_df.mean().mean())
#what cities are the most similar
#print(f'{cosine_similarities_df.mean().idxmax()} is the city with the most similarities with an average of {cosine_similarities_df.mean().max()}')
#print(f'{cosine_similarities_df.mean().idxmin()} is the city with the least similarities with an average of {cosine_similarities_df.mean().min()}')
print("Max: ", cosine_similarities_df.mean().max())
print("Min: ", cosine_similarities_df.mean().min())
print("Median: ", cosine_similarities_df.mean().median())
print("Std: ", cosine_similarities_df.mean().std())
# Out:
# Mean:  0.27265955162501954
# Max:  0.3234180482626023
# Min:  0.0607601511046555
# Median:  0.28709047040285185
# Std:  0.04197296391554417

# %%
#check similarity of ['Zagreb', 'Vienna', 'Rome', 'Lisbon', 'Venice', 'Miami', 'Belgrade', 'Kiribati']
cities_to_compare = ['Zagreb', 'Vienna', 'Rome', 'Lisbon', 'Venice', 'Miami', 'Belgrade', 'Kiritimati']


cosine_similairties_df_filtered = cosine_similarities_df.loc[cities_to_compare, cities_to_compare]

cosine_similairties_df_filtered
# Out:
#               Zagreb    Vienna      Rome    Lisbon    Venice     Miami  \
# Zagreb      1.000000  0.274107  0.302354  0.235276  0.298231  0.161738
# Vienna      0.274107  1.000000  0.338250  0.311793  0.320565  0.193400
# Rome        0.302354  0.338250  1.000000  0.292537  0.319280  0.335452
# Lisbon      0.235276  0.311793  0.292537  1.000000  0.314277  0.226862
# Venice      0.298231  0.320565  0.319280  0.314277  1.000000  0.234633
# Miami       0.161738  0.193400  0.335452  0.226862  0.234633  1.000000
# Belgrade    0.221466  0.331691  0.304071  0.321786  0.346301  0.192904
# Kiritimati  0.299899  0.246402  0.333638  0.284216  0.236646  0.240060
#
#             Belgrade  Kiritimati
# Zagreb      0.221466    0.299899
# Vienna      0.331691    0.246402
# Rome        0.304071    0.333638
# Lisbon      0.321786    0.284216
# Venice      0.346301    0.236646
# Miami       0.192904    0.240060
# Belgrade    1.000000    0.217279
# Kiritimati  0.217279    1.000000

# %% [markdown]
# # TFIDF

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)

# %%
print(text_df)
# Out:
# shape: (1_954, 2)
# ┌─────────────────┬─────────────────────────────────┐
# │ node            ┆ content                         │
# │ ---             ┆ ---                             │
# │ str             ┆ str                             │
# ╞═════════════════╪═════════════════════════════════╡
# │ Whitehorse      ┆ Archaeological research south … │
# │ Dijon           ┆ The earliest archaeological fi… │
# │ Bhubaneswar     ┆ Bhubaneswar stands near the ru… │
# │ Paris           ┆ ===Origins===                   │
# │                 ┆                                 │
# │                 ┆ The ''Parisii (…                │
# │ Dire Dawa       ┆ === Origins ===                 │
# │                 ┆                                 │
# │                 ┆                                 │
# │                 ┆ The region w…                   │
# │ …               ┆ …                               │
# │ Kenora          ┆ Kenora is situated on the trad… │
# │ Lansdowne House ┆ It was designed by Robert Adam… │
# │ Kostanay        ┆ Kostanay was founded by Russia… │
# │ Chumphon        ┆ Chumphon volunteers fought inv… │
# │ Tanjung Pinang  ┆ The name ''Tanjungpinang'' is … │
# └─────────────────┴─────────────────────────────────┘

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')

# get all the tokens that refer to the same genre
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
#stop_words.update(['http','title', 'short', 'description', ' ', 'wa'])

genre_content_dict = {}
for row in text_df.iter_rows(named=True):
    city = row["node"]
    city_text = row["content"]

    # Tokenize text
    tokens = word_tokenize(city_text)
    # Convert to lowercase and remove punctuation
    tokens = [word.lower() for word in tokens if word.isalnum()]
    # Lemmatize tokens
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    # remove single characters
    tokens = [word for word in tokens if len(word) > 1]

    content = " ".join(tokens)
    genre_content_dict[city] = content
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Calculate TF-IDF for each genre
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, min_df=2, stop_words="english")
tfidf_matrix = tfidf_vectorizer.fit_transform(genre_content_dict.values())
feature_names = tfidf_vectorizer.get_feature_names_out()

# %%
cosine_sim_matrix = cosine_similarity(tfidf_matrix)

cosine_sim_df = pd.DataFrame(cosine_sim_matrix, index=cities, columns=cities)

# %%
cosine_sim_df
# Out:
#                  Whitehorse     Dijon  Bhubaneswar     Paris  Dire Dawa  \
# Whitehorse         1.000000  0.014597     0.025687  0.041458   0.033365
# Dijon              0.014597  1.000000     0.015785  0.147315   0.027424
# Bhubaneswar        0.025687  0.015785     1.000000  0.031109   0.027196
# Paris              0.041458  0.147315     0.031109  1.000000   0.038780
# Dire Dawa          0.033365  0.027424     0.027196  0.038780   1.000000
# ...                     ...       ...          ...       ...        ...
# Kenora             0.079846  0.029503     0.019236  0.043148   0.025178
# Lansdowne House    0.017073  0.009100     0.008456  0.023437   0.011608
# Kostanay           0.029152  0.033571     0.021526  0.033954   0.036643
# Chumphon           0.016759  0.013801     0.002097  0.011983   0.022986
# Tanjung Pinang     0.027053  0.017151     0.027413  0.033671   0.023161
#
#                  Ubon Ratchathani  Rahim Yar Khan  Biratnagar  Point Barrow  \
# Whitehorse               0.013480        0.014176    0.021552      0.013388
# Dijon                    0.021817        0.008594    0.025306      0.014337
# Bhubaneswar              0.011837        0.012650    0.073077      0.020102
# Paris                    0.024661        0.021050    0.035000      0.011849
# Dire Dawa                0.016561        0.011014    0.025841      0.010560
# ...                           ...             ...         ...           ...
# Kenora                   0.015313        0.013494    0.027376      0.009905
# Lansdowne House          0.004791        0.002263    0.007522      0.010468
# Kostanay                 0.020749        0.037913    0.027698      0.020689
# Chumphon                 0.021256        0.000000    0.000000      0.000000
# Tanjung Pinang           0.023107        0.018287    0.026903      0.008755
#
#                  Mexico City  ...  Libreville  Ornskoldsvik    Bratsk  \
# Whitehorse          0.055658  ...    0.035784      0.011118  0.049530
# Dijon               0.052051  ...    0.035287      0.036300  0.022899
# Bhubaneswar         0.044546  ...    0.021629      0.012866  0.028444
# Paris               0.084973  ...    0.088847      0.025241  0.038026
# Dire Dawa           0.050496  ...    0.035256      0.021981  0.037274
# ...                      ...  ...         ...           ...       ...
# Kenora              0.044467  ...    0.031524      0.013557  0.030807
# Lansdowne House     0.027261  ...    0.007941      0.004751  0.012164
# Kostanay            0.062786  ...    0.028943      0.029174  0.048608
# Chumphon            0.012646  ...    0.004083      0.000000  0.019843
# Tanjung Pinang      0.046968  ...    0.031510      0.006417  0.025211
#
#                    Bilbao    Koumac    Kenora  Lansdowne House  Kostanay  \
# Whitehorse       0.031757  0.023938  0.079846         0.017073  0.029152
# Dijon            0.034528  0.017719  0.029503         0.009100  0.033571
# Bhubaneswar      0.027358  0.014870  0.019236         0.008456  0.021526
# Paris            0.057198  0.037513  0.043148         0.023437  0.033954
# Dire Dawa        0.037547  0.017350  0.025178         0.011608  0.036643
# ...                   ...       ...       ...              ...       ...
# Kenora           0.031216  0.027193  1.000000         0.019232  0.023295
# Lansdowne House  0.014010  0.004647  0.019232         1.000000  0.005276
# Kostanay         0.045725  0.008457  0.023295         0.005276  1.000000
# Chumphon         0.007304  0.000000  0.014425         0.000000  0.017106
# Tanjung Pinang   0.038445  0.025278  0.020185         0.010844  0.029652
#
#                  Chumphon  Tanjung Pinang
# Whitehorse       0.016759        0.027053
# Dijon            0.013801        0.017151
# Bhubaneswar      0.002097        0.027413
# Paris            0.011983        0.033671
# Dire Dawa        0.022986        0.023161
# ...                   ...             ...
# Kenora           0.014425        0.020185
# Lansdowne House  0.000000        0.010844
# Kostanay         0.017106        0.029652
# Chumphon         1.000000        0.015421
# Tanjung Pinang   0.015421        1.000000
#
# [1954 rows x 1954 columns]

# %%
genre_content_dict['Salamanca']
# Out:
# 'salamanca universal history salamanca ha linked universal history series event personality came mark evolution western society creation first grammar spanish language 1492 antonio de nebrija famous gramática de la lengua castellana wa first study rule western european language latin fact mark beginning spanish golden age preparation christopher columbus first voyage history discovery america cloister university salamanca met council discus project year columbus obtained support dominican staying convento de san esteban de san esteban salamanca astronomer abraham zacuto wa great scientific support trip year study hernán cortés leaving america conquering aztec empire defense right native new world school salamanca francisco de vitoria head reformulated concept natural law renewed theology laid foundation modern law nation international law modern economic science actively participated council trent council mathematician university salamanca proposed pope gregory xiii calendar came known gregorian calendar currently used world germ wa two study carried 1515 1578 scientist university submitted church partial translation bible spanish made luis de luis de león oldest preserved printed book modern chess repetición de amores arte de ajedrez religious luis ramírez de lucena published salamanca 1496 stay miguel de cervantes possible student university influenced book cueva de cueva de salamanca quixote la mancha make reference salamanca character bachelor sansón carrasco la tía fingida el licenciado vidriera antiquity first human habitat salamanca area ha dated beginning first millennium bc attested ceramic remains found cerro de san vicente archaeological park salamanca vicente hill ascribed la cogotas culture bronze bronze age hill ha found date considered first human settlement stable continuous character although already ascribed culture soto de medinilla iron iron age 7th century bc later already iron iron age 4th century bc ha found new population center developed teso de la catedrales cerro de san isidro already castro spain character lasted definitive romanization city settlement therefore current site salamanca owe existence special geomorphological characteristic terrain settled thus choice location successive settlement must special influence fact area three tessera erosion san francisco santo domingo corresponding watercourse especially proximity tormes river detail point suitability territory primitive function defense control surrounding territory settlement hill san isidro must city great importance century 4th 2nd century bc dimension also optimal orographic condition defensive protection since wall moat 220 hannibal advance iberia besieged conquered ancient city helmantica salamanca thus plutarch say hannibal besieged inhabitant avoid damage submitted offering three hundred talent silver many hostage raising siege helmantiqueses failed keep promise protected woman hidden weapon managed defeat hannibal troop however carthaginian general ended seizing according polybius admired bravery woman returned men homeland wealth second punic war victorious ancient army began expansion throughout iberian peninsula salamanca began intense period romanization city annexed province lusitania roman salmantica wa restructured limiting settlement teso de la catedrales abandoning site hill san vicente new configuration kept remarkable city particular defensive accessibility characteristic also center exchange three cultural element greatest influence configuration development city salamanca come roman period first place vía de la de la plata considered main communication infrastructure main axis city planning milestone development commercial function secondly roman bridge bridge infrastructure since 1st century guaranteed passage tormes river therefore access city south roman bridge still remains today northern half since half rebuilt 17th century san policarpo flood finally cerca vieja primitive wall city surrounded perimeter hill san  ...

# %%
print("Mean: ", cosine_sim_df.mean().mean())
print(f'{cosine_sim_df.mean().idxmax()} is the city with the most similarities with an average of {cosine_sim_df.mean().max()}')
print(f'{cosine_sim_df.mean().idxmin()} is the city with the least similarities with an average of {cosine_sim_df.mean().min()}')
print("Median: ", cosine_sim_df.mean().median())
print("Std: ", cosine_sim_df.mean().std())
# Out:
# Mean:  0.028734383109956005
# Salamanca is the city with the most similarities with an average of 0.07182723288695388
# Rennes is the city with the least similarities with an average of 0.0
# Median:  0.02810618024819736
# Std:  0.009510800391360472

# %%
# Extract top 100 words for each city
top_words_per_city = {}
for city in cities:
    city_tfidf_vector = tfidf_matrix[cities.index(city)]
    # Get indices of top 100 words based on TF-IDF scores
    top_word_indices = city_tfidf_vector.toarray()[0].argsort()[-100:][::-1]
    # Get actual words using feature names
    top_words = [feature_names[i] for i in top_word_indices]
    top_words_per_city[city] = top_words

# Filter TF-IDF matrix to include only top words
all_top_words = set().union(*top_words_per_city.values())  # Combine top words from all cities
top_word_indices = [i for i, word in enumerate(feature_names) if word in all_top_words]
filtered_tfidf_matrix = tfidf_matrix[:, top_word_indices]

# %%
cosine_similarities_top = cosine_similarity(filtered_tfidf_matrix)
cosine_similarities_top_df = pd.DataFrame(cosine_similarities_top, index=cities, columns=cities)
cosine_similarities_top_df
# Out:
#                  Whitehorse     Dijon  Bhubaneswar     Paris  Dire Dawa  \
# Whitehorse         1.000000  0.014597     0.025687  0.041565   0.033365
# Dijon              0.014597  1.000000     0.015785  0.147692   0.027424
# Bhubaneswar        0.025687  0.015785     1.000000  0.031189   0.027196
# Paris              0.041565  0.147692     0.031189  1.000000   0.038880
# Dire Dawa          0.033365  0.027424     0.027196  0.038880   1.000000
# ...                     ...       ...          ...       ...        ...
# Kenora             0.079846  0.029503     0.019236  0.043258   0.025178
# Lansdowne House    0.017073  0.009100     0.008456  0.023497   0.011608
# Kostanay           0.029152  0.033571     0.021526  0.034041   0.036643
# Chumphon           0.016759  0.013801     0.002097  0.012013   0.022986
# Tanjung Pinang     0.027053  0.017151     0.027413  0.033757   0.023161
#
#                  Ubon Ratchathani  Rahim Yar Khan  Biratnagar  Point Barrow  \
# Whitehorse               0.013480        0.014176    0.021552      0.013388
# Dijon                    0.021817        0.008594    0.025306      0.014337
# Bhubaneswar              0.011837        0.012650    0.073077      0.020102
# Paris                    0.024724        0.021104    0.035089      0.011880
# Dire Dawa                0.016561        0.011014    0.025841      0.010560
# ...                           ...             ...         ...           ...
# Kenora                   0.015313        0.013494    0.027376      0.009905
# Lansdowne House          0.004791        0.002263    0.007522      0.010468
# Kostanay                 0.020749        0.037913    0.027698      0.020689
# Chumphon                 0.021256        0.000000    0.000000      0.000000
# Tanjung Pinang           0.023107        0.018287    0.026903      0.008755
#
#                  Mexico City  ...  Libreville  Ornskoldsvik    Bratsk  \
# Whitehorse          0.055754  ...    0.035784      0.011118  0.049530
# Dijon               0.052140  ...    0.035287      0.036300  0.022899
# Bhubaneswar         0.044622  ...    0.021629      0.012866  0.028444
# Paris               0.085337  ...    0.089074      0.025305  0.038124
# Dire Dawa           0.050583  ...    0.035256      0.021981  0.037274
# ...                      ...  ...         ...           ...       ...
# Kenora              0.044543  ...    0.031524      0.013557  0.030807
# Lansdowne House     0.027308  ...    0.007941      0.004751  0.012164
# Kostanay            0.062894  ...    0.028943      0.029174  0.048608
# Chumphon            0.012667  ...    0.004083      0.000000  0.019843
# Tanjung Pinang      0.047048  ...    0.031510      0.006417  0.025211
#
#                    Bilbao    Koumac    Kenora  Lansdowne House  Kostanay  \
# Whitehorse       0.031768  0.023938  0.079846         0.017073  0.029152
# Dijon            0.034541  0.017719  0.029503         0.009100  0.033571
# Bhubaneswar      0.027369  0.014870  0.019236         0.008456  0.021526
# Paris            0.057366  0.037609  0.043258         0.023497  0.034041
# Dire Dawa        0.037561  0.017350  0.025178         0.011608  0.036643
# ...                   ...       ...       ...              ...       ...
# Kenora           0.031228  0.027193  1.000000         0.019232  0.023295
# Lansdowne House  0.014016  0.004647  0.019232         1.000000  0.005276
# Kostanay         0.045742  0.008457  0.023295         0.005276  1.000000
# Chumphon         0.007307  0.000000  0.014425         0.000000  0.017106
# Tanjung Pinang   0.038459  0.025278  0.020185         0.010844  0.029652
#
#                  Chumphon  Tanjung Pinang
# Whitehorse       0.016759        0.027053
# Dijon            0.013801        0.017151
# Bhubaneswar      0.002097        0.027413
# Paris            0.012013        0.033757
# Dire Dawa        0.022986        0.023161
# ...                   ...             ...
# Kenora           0.014425        0.020185
# Lansdowne House  0.000000        0.010844
# Kostanay         0.017106        0.029652
# Chumphon         1.000000        0.015421
# Tanjung Pinang   0.015421        1.000000
#
# [1954 rows x 1954 columns]

# %%
print("Mean: ", cosine_similarities_top_df.mean().mean())
print(f'{cosine_similarities_top_df.mean().idxmax()} is the city with the most similarities with an average of {cosine_similarities_top_df.mean().max()}')
print(f'{cosine_similarities_top_df.mean().idxmin()} is the city with the least similarities with an average of {cosine_similarities_top_df.mean().min()}')
print("Median: ", cosine_similarities_top_df.mean().median())
print("Std: ", cosine_similarities_top_df.mean().std())
# Out:
# Mean:  0.028753491045108735
# Salamanca is the city with the most similarities with an average of 0.0722482980244132
# Rennes is the city with the least similarities with an average of 0.0
# Median:  0.02812178822841234
# Std:  0.009526708046953545

# %% [markdown]
# # Plot graph

# %%
routes = pd.read_csv('routes.csv')
airports = pd.read_csv('airports.csv')

# %%
airports.head()
# Out:
#                                           Name          City  \
# 0                               Goroka Airport        Goroka
# 1                               Madang Airport        Madang
# 2                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3                               Nadzab Airport        Nadzab
# 4  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude   Longitude  Altitude Timezone DST  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282       10   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789002        20       10   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388       10   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239       10   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146       10   U
#
#              Timezone.1
# 0  Pacific/Port_Moresby
# 1  Pacific/Port_Moresby
# 2  Pacific/Port_Moresby
# 3  Pacific/Port_Moresby
# 4  Pacific/Port_Moresby

# %%
for node in G_loaded.nodes():
    lat, lon = airports.loc[airports['City'] == node, ['Latitude', 'Longitude']].values[0]
    G_loaded.nodes[node]['coords'] = (lon, lat)

# %%
# !pip install cartopy
# Out:
# Collecting cartopy
#   Downloading Cartopy-0.24.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.8.0)
# Requirement already satisfied: shapely>=1.8 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.0.6)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from cartopy) (24.2)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->cartopy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->cartopy) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->cartopy) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->cartopy) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->cartopy) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.3.1->cartopy) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Downloading Cartopy-0.24.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 42.9 MB/s eta 0:00:00
# Installing collected packages: cartopy
# Successfully installed cartopy-0.24.1

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io.shapereader import natural_earth

positions = {node: data['coords'] for node, data in G_loaded.nodes(data=True)}

fig, ax = plt.subplots(figsize=(12, 6), subplot_kw={'projection': ccrs.PlateCarree()})

ax.set_extent([-180, 180, -90, 90], crs=ccrs.PlateCarree())

# Add detailed features
ax.add_feature(cfeature.LAND, facecolor="#f0e4d3")
ax.add_feature(cfeature.OCEAN, facecolor="#a6cee3")
ax.add_feature(cfeature.COASTLINE, edgecolor="black", linewidth=0.7)
ax.add_feature(cfeature.BORDERS, linestyle=":", edgecolor="gray")
ax.add_feature(cfeature.LAKES, facecolor="#a6cee3", edgecolor="blue", alpha=0.5)
ax.add_feature(cfeature.RIVERS, edgecolor="blue", alpha=0.7)


nx.draw_networkx_edges(G_loaded, positions, ax=ax, edge_color='black', alpha=0.7, width=0.5)
nx.draw_networkx_nodes(G_loaded, positions, ax=ax, node_size=25, node_color='red')

plt.title("Airport Routes on World Map")
plt.show()
